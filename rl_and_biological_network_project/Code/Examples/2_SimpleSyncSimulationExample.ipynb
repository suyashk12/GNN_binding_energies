# %% [markdown]
# This jupyter gives you a simple example of how you should use the Simulated Network (asynchronous) environment. This environment is not meant as a training ground of your algorithms, but only to check whether or not your algorithm can be executed and if it is fast enough to create a response in time. (Set stim_period = 100 to be sure).

# %%
import gymnasium as gym
import numpy as np

# Add parent directory to path
import sys
from pathlib import Path
current_dir = Path().resolve()
root_dir = current_dir.parent
if str(root_dir) not in sys.path:
    sys.path.insert(0,str(root_dir))

from Gyms.SimulatedNetworkSync import SimulatedNetworkSync

# %%
# Define size of state and action spaces, as well as stimulation period
state_dim   = 4   # Dimension of reduced state space
action_dim  = 5   # Number of stimuli in action space. Must be less or equal to 5 (each stimulus needs a value of {0,1,2,3,4}
stim_period = 250 # stimulation period, meaning that an action is applied every {stim_period} ms

# %%
# Create environment and initialize it
env      = SimulatedNetworkSync(action_dim=action_dim,state_dim=state_dim,stim_period=stim_period)
state, _ = env.reset()
env.render() # This function gives you the current state + reward, which both is 0 after initialization
# Out:
# Current state: [0. 0. 0. 0.], Reward: 0

# %%
# Example code, that stimulates the network 100 times with a randomly sampled action, while calculating also the average reward received

total_reward = 0
action_count = 0

for _ in range(100):
    # For simplicity, choose a random action
    action = env.action_space.sample()
    print(f"Stimulate with action: {action}")
    
    state, reward, terminated, truncated, info = env.step(action)
    total_reward += reward
    action_count += 1

    # Plot information
    print(f"Info: {info}")

    print("-----------------------------")
# Out:
# Stimulate with action: [0 4 2 3 3]
# Info: {'spikes': array([ 8.11537054, 11.60236532, 13.05728006, 15.49966165, 16.10810155,
#        19.71623226, 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 1, 2, 2, 3, 2, 3]), 'action': array([0, 4, 2, 3, 3]), 'missed_cyc': 0, 'stim_id': 1, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 2 4 2 1]
# Info: {'spikes': array([ 3.60988065,  8.59013324, 10.590654  , 11.4416555 , 12.52081835,
#        16.22640751, 16.27013669, 19.35798756, 19.9999    , 19.9999    ]), 'elecs': array([2, 1, 3, 3, 2, 1, 0, 0, 2, 1]), 'action': array([3, 2, 4, 2, 1]), 'missed_cyc': 0, 'stim_id': 2, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 0 3 1 3]
# Info: {'spikes': array([ 1.54432552,  8.20839701, 12.5148126 , 14.22289676, 15.85638461,
#        19.57488567, 19.88403365, 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 2, 0, 3, 2, 1, 1, 3]), 'action': array([4, 0, 3, 1, 3]), 'missed_cyc': 0, 'stim_id': 3, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 2 0 4 2]
# Info: {'spikes': array([ 3.30629226,  8.35153755,  8.48499029, 11.88910873, 16.6092493 ,
#        19.00114171, 19.86760714, 19.9999    ]), 'elecs': array([3, 1, 0, 2, 3, 1, 0, 2]), 'action': array([4, 2, 0, 4, 2]), 'missed_cyc': 0, 'stim_id': 4, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 2 1 3 1]
# Info: {'spikes': array([ 3.09972249,  5.08399813,  7.57495373,  8.43961837,  9.38459936,
#        11.1764724 , 14.02798056, 15.07469337, 17.10823228, 19.50161709,
#        19.9999    , 19.9999    ]), 'elecs': array([0, 3, 0, 1, 3, 0, 2, 1, 2, 3, 0, 1]), 'action': array([4, 2, 1, 3, 1]), 'missed_cyc': 0, 'stim_id': 5, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 3 1 0 3]
# Info: {'spikes': array([ 6.17108911,  7.6585233 ,  7.96565943, 12.18368545, 14.07721271,
#        16.91014813, 17.9622084 , 19.59129361, 19.9999    ]), 'elecs': array([3, 2, 0, 0, 3, 1, 3, 2, 3]), 'action': array([4, 3, 1, 0, 3]), 'missed_cyc': 0, 'stim_id': 6, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0 0 3 1]
# Info: {'spikes': array([ 0.56363788,  3.26120202,  8.26654361, 16.06496001, 19.9999    ,
#        19.9999    , 19.9999    ]), 'elecs': array([1, 1, 2, 2, 3, 0, 1]), 'action': array([2, 0, 0, 3, 1]), 'missed_cyc': 0, 'stim_id': 7, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0 2 1 3]
# Info: {'spikes': array([ 4.42745347,  8.1635487 , 11.42171   , 15.0674375 , 15.35486088,
#        19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([1, 2, 1, 2, 0, 1, 2, 3]), 'action': array([2, 0, 2, 1, 3]), 'missed_cyc': 0, 'stim_id': 8, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 0 3 1 4]
# Info: {'spikes': array([11.59350391, 16.58299884, 18.03248713, 19.9999    , 19.9999    ,
#        19.9999    ]), 'elecs': array([2, 3, 0, 1, 3, 0]), 'action': array([0, 0, 3, 1, 4]), 'missed_cyc': 0, 'stim_id': 9, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 4 0 0 4]
# Info: {'spikes': array([ 3.67641696,  6.34754257,  8.75536438, 13.82435496, 19.9999    ,
#        19.9999    ]), 'elecs': array([2, 3, 3, 0, 3, 0]), 'action': array([3, 4, 0, 0, 4]), 'missed_cyc': 0, 'stim_id': 10, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 1 2 2 3]
# Info: {'spikes': array([ 8.28275437, 11.6317182 , 12.55506755, 13.81588812, 15.28733966,
#        18.00026197, 19.35281791, 19.984415  , 19.9999    ]), 'elecs': array([0, 1, 1, 3, 2, 1, 2, 2, 3]), 'action': array([0, 1, 2, 2, 3]), 'missed_cyc': 0, 'stim_id': 11, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 4 4 2 0]
# Info: {'spikes': array([ 0.32597501,  2.47461611,  8.52656352,  9.52593052, 11.3054853 ,
#        14.08232675, 15.93724252, 16.85198485, 18.15368991]), 'elecs': array([0, 2, 3, 3, 3, 0, 0, 1, 2]), 'action': array([3, 4, 4, 2, 0]), 'missed_cyc': 0, 'stim_id': 12, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 0 4 3 3]
# Info: {'spikes': array([12.4527365 , 17.09458122, 17.75426865, 19.49624122, 19.9999    ,
#        19.9999    ]), 'elecs': array([3, 0, 2, 2, 3, 3]), 'action': array([0, 0, 4, 3, 3]), 'missed_cyc': 0, 'stim_id': 13, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3 2 4 1]
# Info: {'spikes': array([ 2.86712445,  8.11581188,  9.55489457, 11.43175335, 12.81453386,
#        15.97990095, 17.54260732, 19.24053232, 19.9999    , 19.9999    ]), 'elecs': array([0, 1, 2, 3, 1, 2, 3, 0, 0, 1]), 'action': array([1, 3, 2, 4, 1]), 'missed_cyc': 0, 'stim_id': 14, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 4 4 2 1]
# Info: {'spikes': array([ 3.81428518,  7.20370089,  8.01705144, 10.67329303, 12.65387932,
#        15.1460618 , 15.95398637, 19.26202528, 19.9999    , 19.9999    ]), 'elecs': array([0, 3, 1, 3, 0, 0, 1, 2, 0, 1]), 'action': array([1, 4, 4, 2, 1]), 'missed_cyc': 0, 'stim_id': 15, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1 0 1 0]
# Info: {'spikes': array([ 4.54558009,  8.84237214,  9.07855067, 12.11844495, 15.21882437,
#        19.9999    ]), 'elecs': array([0, 0, 1, 1, 0, 1]), 'action': array([1, 1, 0, 1, 0]), 'missed_cyc': 0, 'stim_id': 16, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 1 0 3 3]
# Info: {'spikes': array([ 0.12496521,  4.58905573,  7.32981629,  8.90265872, 12.15907432,
#        15.44838301, 19.07257771, 19.9999    , 19.9999    ]), 'elecs': array([3, 2, 0, 3, 1, 2, 3, 2, 3]), 'action': array([3, 1, 0, 3, 3]), 'missed_cyc': 0, 'stim_id': 17, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3 3 2 1]
# Info: {'spikes': array([ 2.10166192,  5.65589665,  8.69713396,  9.97461225, 10.99407176,
#        13.37829013, 14.98700043, 16.42280209, 18.53866277, 19.3398863 ,
#        19.9999    ]), 'elecs': array([1, 0, 1, 2, 2, 3, 1, 3, 0, 2, 1]), 'action': array([1, 3, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 18, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 0 4 3 2]
# Info: {'spikes': array([ 3.02642005,  5.4464137 ,  6.87983827, 11.79370176, 14.53309005,
#        16.72345858, 18.87661425, 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 1, 3, 2, 0, 1, 3, 2]), 'action': array([4, 0, 4, 3, 2]), 'missed_cyc': 0, 'stim_id': 19, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3 4 2 3]
# Info: {'spikes': array([ 5.13946229,  9.32870502,  9.37584941, 12.08383014, 12.59073915,
#        15.00432199, 15.8858093 , 19.29773464, 19.9999    , 19.9999    ]), 'elecs': array([0, 1, 2, 3, 3, 0, 1, 2, 2, 3]), 'action': array([1, 3, 4, 2, 3]), 'missed_cyc': 0, 'stim_id': 20, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 0 1 4 1]
# Info: {'spikes': array([ 4.92993637,  8.42822856, 12.09250578, 16.62256063, 18.04805291,
#        19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([0, 1, 0, 1, 3, 0, 0, 1]), 'action': array([1, 0, 1, 4, 1]), 'missed_cyc': 0, 'stim_id': 21, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 3 4 2 2]
# Info: {'spikes': array([ 8.90575426, 11.00441742, 11.74764019, 15.35615282, 17.37920468,
#        19.84193986, 19.9999    , 19.9999    ]), 'elecs': array([2, 3, 3, 0, 1, 2, 1, 2]), 'action': array([0, 3, 4, 2, 2]), 'missed_cyc': 0, 'stim_id': 22, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 3 0 1 2]
# Info: {'spikes': array([ 1.41254195,  4.01102334,  5.79535765,  9.29780791, 11.26757497,
#        15.31446047, 19.08747326, 19.9999    , 19.9999    ]), 'elecs': array([3, 1, 2, 2, 3, 0, 1, 1, 2]), 'action': array([2, 3, 0, 1, 2]), 'missed_cyc': 0, 'stim_id': 23, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 4 2 3 2]
# Info: {'spikes': array([ 8.91860911,  9.6444359 , 12.23057933, 16.94633918, 18.82367596,
#        19.75317077, 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 1, 2, 2, 3, 1, 2]), 'action': array([0, 4, 2, 3, 2]), 'missed_cyc': 0, 'stim_id': 24, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 2 0 1 4]
# Info: {'spikes': array([ 1.11983431,  6.70753842,  8.68840073, 11.17486632, 16.43232441,
#        19.25241636, 19.57816299, 19.9999    , 19.9999    ]), 'elecs': array([3, 1, 0, 2, 0, 2, 3, 1, 0]), 'action': array([4, 2, 0, 1, 4]), 'missed_cyc': 0, 'stim_id': 25, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0 4 2 4]
# Info: {'spikes': array([ 2.82978673,  7.03148005, 10.92948739, 15.43258026, 15.88329627,
#        19.06243186, 19.9999    , 19.9999    ]), 'elecs': array([1, 2, 3, 0, 1, 2, 3, 0]), 'action': array([2, 0, 4, 2, 4]), 'missed_cyc': 0, 'stim_id': 26, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 4 0 2 1]
# Info: {'spikes': array([ 4.81316571,  8.70531233,  8.84397169, 11.91541573, 16.92612501,
#        19.54963765, 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 3, 0, 1, 0, 2, 1]), 'action': array([4, 4, 0, 2, 1]), 'missed_cyc': 0, 'stim_id': 27, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 3 4 4 1]
# Info: {'spikes': array([ 3.31362182,  5.11592796,  5.94125933,  8.06393894, 12.31955655,
#        12.9329926 , 15.58971612, 15.9971293 , 19.03178551, 19.9999    ,
#        19.9999    ]), 'elecs': array([3, 0, 2, 0, 3, 3, 0, 3, 0, 0, 1]), 'action': array([4, 3, 4, 4, 1]), 'missed_cyc': 0, 'stim_id': 28, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 3 4 4 4]
# Info: {'spikes': array([ 4.07627808,  8.53627433,  8.55107708, 11.80152978, 13.93792834,
#        15.76434919, 16.9284378 , 18.75433375, 19.9999    , 19.9999    ]), 'elecs': array([3, 2, 0, 3, 3, 3, 0, 3, 0, 0]), 'action': array([4, 3, 4, 4, 4]), 'missed_cyc': 0, 'stim_id': 29, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 4 3 0 0]
# Info: {'spikes': array([ 8.35005752, 12.1240954 , 12.95037395, 16.03583111]), 'elecs': array([3, 2, 0, 3]), 'action': array([0, 4, 3, 0, 0]), 'missed_cyc': 0, 'stim_id': 30, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 2 0 0 1]
# Info: {'spikes': array([ 3.60065141,  8.34592147,  8.59422238,  9.516549  , 12.96681717,
#        13.26563547, 19.41556903, 19.9999    ]), 'elecs': array([1, 3, 1, 2, 2, 2, 0, 1]), 'action': array([2, 2, 0, 0, 1]), 'missed_cyc': 0, 'stim_id': 31, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 2 2 1 2]
# Info: {'spikes': array([ 2.25379447,  7.63520405,  8.90978013, 10.88275968, 11.21212235,
#        15.78390451, 17.28577823, 18.20612092, 19.4410323 , 19.9999    ]), 'elecs': array([1, 2, 1, 2, 1, 2, 0, 1, 1, 2]), 'action': array([2, 2, 2, 1, 2]), 'missed_cyc': 0, 'stim_id': 32, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2 4 3 0]
# Info: {'spikes': array([ 3.03778539,  7.40189496,  8.60280151, 12.51482154, 12.54235267,
#        12.61575565, 15.08904409, 15.64380949, 19.07262053]), 'elecs': array([0, 1, 1, 2, 3, 2, 2, 0, 3]), 'action': array([1, 2, 4, 3, 0]), 'missed_cyc': 0, 'stim_id': 33, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3 4 2 2]
# Info: {'spikes': array([ 5.60498173,  6.02124048,  7.80273987,  9.05956192, 12.08226212,
#        14.74369358, 16.23884073, 16.25029439, 18.86333028, 19.69133794,
#        19.90857608, 19.9999    ]), 'elecs': array([3, 0, 1, 2, 3, 3, 1, 0, 1, 2, 1, 2]), 'action': array([1, 3, 4, 2, 2]), 'missed_cyc': 0, 'stim_id': 34, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 0 0 0 1]
# Info: {'spikes': array([ 4.40685747, 19.9999    , 19.9999    ]), 'elecs': array([1, 0, 1]), 'action': array([0, 0, 0, 0, 1]), 'missed_cyc': 0, 'stim_id': 35, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 2 1 1 4]
# Info: {'spikes': array([ 3.01718083,  5.19352933,  6.30404388,  7.48518446,  7.56378482,
#        12.20415954, 12.61978434, 15.36148565, 15.70251015, 17.907835  ,
#        18.48842599, 19.9999    , 19.9999    ]), 'elecs': array([1, 1, 3, 1, 2, 0, 2, 1, 0, 1, 2, 3, 0]), 'action': array([2, 2, 1, 1, 4]), 'missed_cyc': 0, 'stim_id': 36, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1 3 1 3]
# Info: {'spikes': array([ 4.45419099,  7.82650798,  8.3587501 , 11.87825843, 12.66886465,
#        16.21422684, 17.4802984 , 19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([0, 1, 0, 1, 2, 3, 0, 1, 2, 3]), 'action': array([1, 1, 3, 1, 3]), 'missed_cyc': 0, 'stim_id': 37, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1 4 0 0]
# Info: {'spikes': array([ 4.16573943,  7.59100691,  7.88007402, 11.05475187, 13.06947269,
#        14.97315034, 17.10767768]), 'elecs': array([0, 1, 0, 3, 1, 0, 0]), 'action': array([1, 1, 4, 0, 0]), 'missed_cyc': 0, 'stim_id': 38, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 2 1 4 3]
# Info: {'spikes': array([ 8.08055313, 11.63327676, 12.72266976, 16.69620018, 18.00132582,
#        19.12846984, 19.9999    , 19.9999    ]), 'elecs': array([1, 2, 0, 1, 3, 0, 2, 3]), 'action': array([0, 2, 1, 4, 3]), 'missed_cyc': 0, 'stim_id': 39, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 0 3 2 3]
# Info: {'spikes': array([ 4.34330018,  8.3861436 , 11.12659509, 15.77093835, 16.105966  ,
#        18.40759905, 19.15701047, 19.9999    ]), 'elecs': array([3, 0, 2, 3, 1, 2, 2, 3]), 'action': array([4, 0, 3, 2, 3]), 'missed_cyc': 0, 'stim_id': 40, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 3 1 2 4]
# Info: {'spikes': array([ 6.98000649, 11.61740471, 12.93932325, 15.54241317, 16.10671933,
#        16.20322747, 19.76006292, 19.9999    , 19.9999    ]), 'elecs': array([2, 0, 3, 1, 3, 1, 2, 3, 0]), 'action': array([0, 3, 1, 2, 4]), 'missed_cyc': 0, 'stim_id': 41, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 0 1 4 1]
# Info: {'spikes': array([ 5.85381114,  6.27682137, 11.08396988, 13.99584895, 16.1756233 ,
#        16.51775781, 19.41976838, 19.9999    , 19.9999    ]), 'elecs': array([1, 0, 0, 3, 3, 1, 0, 0, 1]), 'action': array([1, 0, 1, 4, 1]), 'missed_cyc': 0, 'stim_id': 42, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1 0 4 4]
# Info: {'spikes': array([ 5.49063834,  6.0530013 ,  7.63888347,  8.96155991, 10.40697887,
#        18.25481981, 19.12640195, 19.9999    , 19.9999    ]), 'elecs': array([0, 2, 0, 1, 1, 3, 0, 3, 0]), 'action': array([1, 1, 0, 4, 4]), 'missed_cyc': 0, 'stim_id': 43, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 4 2 4 2]
# Info: {'spikes': array([ 1.78665813,  3.15445951,  5.72419334,  8.79341208, 12.28015905,
#        12.42928832, 15.33787673, 17.64025251, 19.9999    , 19.9999    ,
#        19.9999    ]), 'elecs': array([1, 0, 3, 1, 1, 0, 3, 2, 0, 1, 2]), 'action': array([1, 4, 2, 4, 2]), 'missed_cyc': 0, 'stim_id': 44, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1 0 1 2]
# Info: {'spikes': array([ 4.23138849,  8.61437076, 10.00801627, 13.36654869, 15.05293459,
#        18.98435044, 19.62326065, 19.9999    , 19.9999    ]), 'elecs': array([0, 1, 0, 1, 0, 1, 1, 1, 2]), 'action': array([1, 1, 0, 1, 2]), 'missed_cyc': 0, 'stim_id': 45, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 3 4 0 0]
# Info: {'spikes': array([ 4.37807677,  6.53112898,  7.8968478 , 11.35553925, 13.52774655,
#        14.2199125 , 15.2801225 ]), 'elecs': array([3, 2, 0, 3, 3, 3, 0]), 'action': array([4, 3, 4, 0, 0]), 'missed_cyc': 0, 'stim_id': 46, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2 4 2 1]
# Info: {'spikes': array([ 3.87502591,  7.24329961,  7.40710686, 12.0857193 , 14.01354509,
#        15.11430854, 16.83508519, 19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([0, 1, 1, 2, 3, 1, 0, 2, 0, 1]), 'action': array([1, 2, 4, 2, 1]), 'missed_cyc': 0, 'stim_id': 47, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 1 4 2 2]
# Info: {'spikes': array([ 1.26348897,  4.55306439,  7.34100794,  8.40238504, 10.65830278,
#        12.31747688, 14.71837412, 16.59274583, 19.87813207, 19.9999    ,
#        19.9999    ]), 'elecs': array([3, 1, 2, 0, 3, 1, 0, 1, 1, 2, 2]), 'action': array([2, 1, 4, 2, 2]), 'missed_cyc': 0, 'stim_id': 48, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3 2 1 3]
# Info: {'spikes': array([ 4.71889256,  6.52762577,  6.68840084, 11.70721275, 11.99321157,
#        15.28691988, 16.82285217, 19.57885895, 19.9999    , 19.9999    ]), 'elecs': array([0, 1, 2, 3, 1, 2, 0, 2, 1, 3]), 'action': array([1, 3, 2, 1, 3]), 'missed_cyc': 0, 'stim_id': 49, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 1 2 2 4]
# Info: {'spikes': array([ 4.71260856,  5.86107698,  6.55140918, 10.78052737, 13.24085705,
#        15.07275325, 15.96926806, 19.78355043, 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 0, 1, 1, 1, 2, 2, 3, 0]), 'action': array([4, 1, 2, 2, 4]), 'missed_cyc': 0, 'stim_id': 50, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 4 3 3 0]
# Info: {'spikes': array([ 4.93195401,  8.28815414,  8.5512372 , 11.74547251, 12.9247487 ,
#        13.17252508, 16.63312118, 18.15495425, 19.9999    ]), 'elecs': array([1, 2, 3, 2, 0, 0, 2, 3, 3]), 'action': array([2, 4, 3, 3, 0]), 'missed_cyc': 0, 'stim_id': 51, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 3 2 2 4]
# Info: {'spikes': array([ 3.82421427,  8.93917852,  9.05739386, 11.95735466, 12.49192962,
#        17.59563083, 17.74655926, 19.27756831, 19.9999    , 19.9999    ]), 'elecs': array([2, 2, 3, 3, 1, 1, 2, 2, 3, 0]), 'action': array([3, 3, 2, 2, 4]), 'missed_cyc': 0, 'stim_id': 52, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0 3 3 1]
# Info: {'spikes': array([ 3.91283831,  7.97319402, 11.1885189 , 12.59743063, 14.48415959,
#        14.88587707, 18.83137918, 19.9999    , 19.9999    ]), 'elecs': array([1, 2, 2, 2, 3, 2, 3, 0, 1]), 'action': array([2, 0, 3, 3, 1]), 'missed_cyc': 0, 'stim_id': 53, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 0 2 4 3]
# Info: {'spikes': array([ 3.80073745,  8.0909275 , 14.2676608 , 15.0259138 , 16.45990039,
#        19.5147038 , 19.9999    , 19.9999    ]), 'elecs': array([2, 3, 1, 2, 3, 0, 2, 3]), 'action': array([3, 0, 2, 4, 3]), 'missed_cyc': 0, 'stim_id': 54, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2 2 1 4]
# Info: {'spikes': array([ 5.6486073 ,  7.22045188,  9.13743115, 10.73928802, 12.4503075 ,
#        16.61876221, 16.79994517, 19.43307054, 19.9999    , 19.9999    ]), 'elecs': array([0, 1, 1, 2, 1, 2, 0, 3, 1, 0]), 'action': array([1, 2, 2, 1, 4]), 'missed_cyc': 0, 'stim_id': 55, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 2 0 3 1]
# Info: {'spikes': array([ 3.96488632,  7.7745834 ,  8.31662224,  9.84680803, 15.68159051,
#        17.82093504, 18.79823636, 19.20641594, 19.9999    ]), 'elecs': array([2, 3, 1, 2, 3, 2, 0, 3, 1]), 'action': array([3, 2, 0, 3, 1]), 'missed_cyc': 0, 'stim_id': 56, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 1 0 0 2]
# Info: {'spikes': array([ 5.50814446,  8.36531221, 12.24234334, 19.9999    , 19.9999    ]), 'elecs': array([2, 0, 1, 1, 2]), 'action': array([0, 1, 0, 0, 2]), 'missed_cyc': 0, 'stim_id': 57, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 1 1 3 2]
# Info: {'spikes': array([ 3.9977044 ,  5.92413901,  6.83145788, 10.89767372, 11.54851513,
#        15.71490595, 17.25735708, 19.45761942, 19.69944364, 19.9999    ]), 'elecs': array([2, 3, 0, 0, 1, 2, 1, 1, 3, 2]), 'action': array([3, 1, 1, 3, 2]), 'missed_cyc': 0, 'stim_id': 58, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0 3 0 0]
# Info: {'spikes': array([ 4.96138102,  6.1516113 , 12.42858658, 16.92431679]), 'elecs': array([1, 2, 2, 3]), 'action': array([2, 0, 3, 0, 0]), 'missed_cyc': 0, 'stim_id': 59, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3 1 3 4]
# Info: {'spikes': array([ 6.03602689,  7.2308952 ,  7.99027511, 11.16590016, 13.09176699,
#        16.14882336, 16.5508907 , 17.25528936, 18.52021936, 19.9999    ,
#        19.9999    ]), 'elecs': array([0, 2, 1, 3, 0, 2, 1, 1, 3, 3, 0]), 'action': array([1, 3, 1, 3, 4]), 'missed_cyc': 0, 'stim_id': 60, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 1 0 0 3]
# Info: {'spikes': array([ 3.06083203,  7.37699314,  7.89590961, 12.30597875, 19.9999    ,
#        19.9999    ]), 'elecs': array([1, 2, 0, 1, 2, 3]), 'action': array([2, 1, 0, 0, 3]), 'missed_cyc': 0, 'stim_id': 61, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2 3 0 0]
# Info: {'spikes': array([ 2.2138974 ,  3.19401986,  6.61131843,  6.83174554, 11.18760221,
#        11.25419911, 17.79009542, 19.71853838]), 'elecs': array([2, 0, 1, 1, 2, 2, 3, 1]), 'action': array([1, 2, 3, 0, 0]), 'missed_cyc': 0, 'stim_id': 62, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 4 3 2 2]
# Info: {'spikes': array([ 2.42984613,  6.29640489,  8.15587312, 11.7320754 , 12.91596551,
#        16.43552958, 16.76975317, 19.33304517, 19.9999    , 19.9999    ]), 'elecs': array([3, 3, 0, 2, 0, 3, 1, 2, 1, 2]), 'action': array([4, 4, 3, 2, 2]), 'missed_cyc': 0, 'stim_id': 63, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 3 2 3 3]
# Info: {'spikes': array([ 8.44939745, 13.13926997, 15.61064758, 16.27493454, 16.29464816,
#        18.86589765, 19.9999    , 19.9999    ]), 'elecs': array([2, 3, 1, 2, 2, 3, 2, 3]), 'action': array([0, 3, 2, 3, 3]), 'missed_cyc': 0, 'stim_id': 64, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 0 4 0 4]
# Info: {'spikes': array([ 4.4169918 ,  4.64396745,  7.01828994, 12.66947762, 15.91755908,
#        17.71814195, 19.9999    , 19.9999    ]), 'elecs': array([3, 2, 3, 3, 0, 1, 3, 0]), 'action': array([3, 0, 4, 0, 4]), 'missed_cyc': 0, 'stim_id': 65, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 1 0 3 3]
# Info: {'spikes': array([ 0.58899126,  3.61547856,  5.39893535,  7.2406073 ,  8.17428908,
#        12.34671272, 15.516758  , 19.79133063, 19.81816995, 19.9999    ]), 'elecs': array([0, 3, 0, 0, 3, 1, 2, 2, 3, 3]), 'action': array([4, 1, 0, 3, 3]), 'missed_cyc': 0, 'stim_id': 66, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 4 2 2 1]
# Info: {'spikes': array([ 8.06187762, 11.85441098, 12.41524476, 15.47578444, 15.88507715,
#        18.54595333, 19.9999    , 19.9999    ]), 'elecs': array([3, 1, 0, 2, 1, 2, 0, 1]), 'action': array([0, 4, 2, 2, 1]), 'missed_cyc': 0, 'stim_id': 67, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 4 3 3 2]
# Info: {'spikes': array([ 3.00428189,  6.0310538 ,  6.98458463,  7.95594163, 11.97907033,
#        13.03445289, 14.85477046, 15.45983723, 19.47907891, 19.9999    ,
#        19.9999    ]), 'elecs': array([3, 3, 0, 3, 0, 2, 3, 2, 1, 3, 2]), 'action': array([4, 4, 3, 3, 2]), 'missed_cyc': 0, 'stim_id': 68, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0 0 4 2]
# Info: {'spikes': array([ 3.64517392,  5.45581016, 15.33250338, 18.3218831 , 19.87605713,
#        19.9999    ]), 'elecs': array([1, 2, 3, 1, 0, 2]), 'action': array([2, 0, 0, 4, 2]), 'missed_cyc': 0, 'stim_id': 69, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 1 1 4 0]
# Info: {'spikes': array([ 3.66432576,  9.06075566, 10.37402774, 10.6593097 , 12.14556791,
#        12.39141264, 15.53750104, 16.80213929, 19.8240969 ]), 'elecs': array([3, 0, 0, 0, 0, 1, 1, 3, 0]), 'action': array([4, 1, 1, 4, 0]), 'missed_cyc': 0, 'stim_id': 70, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 4 2 3 4]
# Info: {'spikes': array([ 4.68989054,  6.6777984 ,  8.45217285, 11.76029936, 13.09373801,
#        15.36253806, 15.93642342, 16.32557559, 19.9999    , 19.9999    ,
#        19.9999    ]), 'elecs': array([0, 3, 1, 1, 0, 2, 2, 1, 3, 3, 0]), 'action': array([1, 4, 2, 3, 4]), 'missed_cyc': 0, 'stim_id': 71, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 2 2 2 1]
# Info: {'spikes': array([ 3.66924087,  7.41142362,  7.61914989, 12.17564675, 14.09370072,
#        15.31136262, 16.37959175, 19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([3, 1, 0, 1, 2, 2, 1, 2, 0, 1]), 'action': array([4, 2, 2, 2, 1]), 'missed_cyc': 0, 'stim_id': 72, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 1 3 0 0]
# Info: {'spikes': array([ 6.85094009, 11.11921022, 12.01774499, 12.04553558, 14.43825882]), 'elecs': array([0, 1, 2, 1, 3]), 'action': array([0, 1, 3, 0, 0]), 'missed_cyc': 0, 'stim_id': 73, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 3 1 4 4]
# Info: {'spikes': array([ 4.92298332,  8.09426669, 12.28248329, 12.76056905, 16.03759061,
#        16.52317036, 19.80705067, 19.9999    , 19.9999    ]), 'elecs': array([2, 2, 0, 3, 3, 1, 0, 3, 0]), 'action': array([0, 3, 1, 4, 4]), 'missed_cyc': 0, 'stim_id': 74, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 4 3 2 3]
# Info: {'spikes': array([ 0.09170515,  5.90319441,  5.97582765,  7.5156592 ,  8.02500295,
#         9.37713605, 11.39210004, 11.52189201, 16.0215826 , 16.48290338,
#        19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([0, 3, 2, 3, 2, 3, 2, 0, 1, 3, 2, 2, 3]), 'action': array([3, 4, 3, 2, 3]), 'missed_cyc': 0, 'stim_id': 75, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 3 3 1 1]
# Info: {'spikes': array([ 4.24250243,  9.42433725,  9.95330731, 11.12393264, 12.61049292,
#        15.54373823, 16.75882848, 19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([2, 2, 3, 2, 3, 3, 0, 1, 0, 1]), 'action': array([3, 3, 3, 1, 1]), 'missed_cyc': 0, 'stim_id': 76, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 2 4 3 0]
# Info: {'spikes': array([ 3.63167059,  6.77196762,  8.42470324, 11.1425278 , 13.69597928,
#        15.9544226 , 16.12899724, 19.9999    ]), 'elecs': array([3, 0, 1, 2, 3, 2, 0, 3]), 'action': array([4, 2, 4, 3, 0]), 'missed_cyc': 0, 'stim_id': 77, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 0 4 3 0]
# Info: {'spikes': array([10.86908443, 15.1655349 , 17.9125692 , 19.9999    ]), 'elecs': array([3, 2, 0, 3]), 'action': array([0, 0, 4, 3, 0]), 'missed_cyc': 0, 'stim_id': 78, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 0 2 4 4]
# Info: {'spikes': array([ 5.36287573,  8.56281807, 11.80534558, 12.99484576, 16.48982428,
#        17.69550436, 18.11989918, 19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 1, 1, 2, 3, 3, 0, 3, 0]), 'action': array([4, 0, 2, 4, 4]), 'missed_cyc': 0, 'stim_id': 79, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2 4 1 1]
# Info: {'spikes': array([ 1.05304801,  4.62559458,  8.06445606,  9.95215545, 11.9201018 ,
#        11.99727682, 13.99660611, 15.80138046, 16.74596831, 19.9999    ,
#        19.9999    , 19.9999    ]), 'elecs': array([3, 0, 1, 1, 2, 2, 3, 0, 0, 1, 0, 1]), 'action': array([1, 2, 4, 1, 1]), 'missed_cyc': 0, 'stim_id': 80, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 3 1 0 2]
# Info: {'spikes': array([ 3.49607716,  7.40493772, 10.83073472, 12.03976582, 14.61141157,
#        14.82433467, 19.9999    , 19.9999    ]), 'elecs': array([0, 2, 3, 0, 3, 1, 1, 2]), 'action': array([0, 3, 1, 0, 2]), 'missed_cyc': 0, 'stim_id': 81, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 1 2 3 4]
# Info: {'spikes': array([ 2.8179462 ,  8.35776894,  8.45716995, 11.41508189, 11.66331704,
#        14.97949394, 15.03282117, 16.56860902, 18.12010758, 19.9999    ,
#        19.9999    ]), 'elecs': array([1, 0, 2, 1, 1, 2, 1, 2, 3, 3, 0]), 'action': array([2, 1, 2, 3, 4]), 'missed_cyc': 0, 'stim_id': 82, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 2 0 3 1]
# Info: {'spikes': array([ 7.93882688, 11.50151333, 14.64582885, 18.7905199 , 19.9999    ,
#        19.9999    , 19.9999    ]), 'elecs': array([1, 2, 2, 3, 3, 0, 1]), 'action': array([0, 2, 0, 3, 1]), 'missed_cyc': 0, 'stim_id': 83, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 1 0 1 2]
# Info: {'spikes': array([ 3.1698851 ,  3.40909882,  5.29662028,  9.9343673 , 12.290844  ,
#        15.02190776, 18.33440751, 19.9999    , 19.9999    ]), 'elecs': array([2, 2, 3, 0, 1, 0, 1, 1, 2]), 'action': array([3, 1, 0, 1, 2]), 'missed_cyc': 0, 'stim_id': 84, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 2 2 2 1]
# Info: {'spikes': array([ 2.2671392 ,  6.30602611,  9.14127994, 10.09104388, 13.79800723,
#        15.40501452, 16.0096566 , 19.84391528, 19.9999    , 19.9999    ]), 'elecs': array([2, 1, 1, 1, 2, 2, 1, 0, 2, 1]), 'action': array([0, 2, 2, 2, 1]), 'missed_cyc': 0, 'stim_id': 85, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1 0 3 1]
# Info: {'spikes': array([ 3.80294274,  8.14645331,  8.45134733, 10.33121816, 17.17341077,
#        19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([0, 1, 0, 1, 2, 3, 0, 1]), 'action': array([1, 1, 0, 3, 1]), 'missed_cyc': 0, 'stim_id': 86, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2 2 1 3]
# Info: {'spikes': array([ 4.41103532,  6.02387575,  7.31125376, 11.63247567, 12.67536957,
#        12.83334448, 14.61335601, 15.32490458, 19.79975617, 19.9999    ,
#        19.9999    ]), 'elecs': array([0, 1, 1, 1, 1, 2, 0, 2, 2, 1, 3]), 'action': array([1, 2, 2, 1, 3]), 'missed_cyc': 0, 'stim_id': 87, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 2 1 0 1]
# Info: {'spikes': array([ 3.30416396,  7.70558214,  8.3018147 , 10.73839282, 11.79631073,
#        12.85909528, 16.00144383, 16.36491855, 19.9999    , 19.9999    ]), 'elecs': array([1, 2, 1, 2, 0, 2, 1, 1, 0, 1]), 'action': array([2, 2, 1, 0, 1]), 'missed_cyc': 0, 'stim_id': 88, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 2 3 2 2]
# Info: {'spikes': array([ 4.93912331,  7.37459539,  7.93601746, 11.35431619, 11.42607156,
#        15.70573637, 17.178561  , 18.74599177, 19.9999    , 19.9999    ,
#        19.9999    ]), 'elecs': array([3, 0, 1, 2, 2, 1, 3, 2, 2, 1, 2]), 'action': array([4, 2, 3, 2, 2]), 'missed_cyc': 0, 'stim_id': 89, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 1 4 3 0]
# Info: {'spikes': array([ 4.38212234,  8.34363155,  9.67099918,  9.77319161, 12.92771327,
#        14.47342827, 16.34997272, 16.36904977, 17.45244086]), 'elecs': array([2, 3, 0, 3, 1, 3, 2, 0, 3]), 'action': array([3, 1, 4, 3, 0]), 'missed_cyc': 0, 'stim_id': 90, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 0 2 2 1]
# Info: {'spikes': array([ 3.40266739,  8.98204026, 11.77833016, 16.2782184 , 17.36912524,
#        19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([2, 3, 1, 1, 2, 2, 0, 1]), 'action': array([3, 0, 2, 2, 1]), 'missed_cyc': 0, 'stim_id': 91, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 3 0 0 3]
# Info: {'spikes': array([ 2.81242289,  4.24307439,  6.46859838,  9.4574839 , 11.81962051,
#        15.4671916 , 18.87949783, 19.9999    ]), 'elecs': array([3, 3, 2, 0, 3, 2, 2, 3]), 'action': array([4, 3, 0, 0, 3]), 'missed_cyc': 0, 'stim_id': 92, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 4 4 2 3]
# Info: {'spikes': array([ 3.52814631,  7.56493598,  7.9638235 , 12.12249485, 14.09373844,
#        15.70532973, 16.54556664, 18.93970939, 19.68305979, 19.9999    ]), 'elecs': array([1, 2, 3, 0, 3, 0, 1, 2, 2, 3]), 'action': array([2, 4, 4, 2, 3]), 'missed_cyc': 0, 'stim_id': 93, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 3 2 2 2]
# Info: {'spikes': array([ 1.15163061,  2.96008948,  7.86142999,  8.53262345, 12.11751501,
#        12.33361669, 15.72135708, 16.6409957 , 18.38236715, 19.9999    ,
#        19.9999    ]), 'elecs': array([2, 3, 2, 0, 3, 1, 2, 1, 1, 2, 2]), 'action': array([4, 3, 2, 2, 2]), 'missed_cyc': 0, 'stim_id': 94, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 3 2 3 1]
# Info: {'spikes': array([ 4.17922379,  7.76754934,  7.86262652, 12.11988525, 12.75275916,
#        16.45313253, 16.55877635, 18.83171305, 19.9999    , 19.9999    ]), 'elecs': array([2, 2, 3, 1, 3, 2, 2, 0, 3, 1]), 'action': array([3, 3, 2, 3, 1]), 'missed_cyc': 0, 'stim_id': 95, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 3 4 4 0]
# Info: {'spikes': array([ 4.50097431,  7.03525773,  9.55340821,  9.88445567, 11.2785079 ,
#        13.68374354, 15.24230385, 16.54030695, 19.10373314]), 'elecs': array([1, 2, 3, 2, 3, 3, 3, 0, 0]), 'action': array([2, 3, 4, 4, 0]), 'missed_cyc': 0, 'stim_id': 96, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 3 1 3 0]
# Info: {'spikes': array([ 5.05233575,  6.38834186,  7.37472213,  9.80053514, 12.29377192,
#        17.44941363, 17.93547136, 19.385966  , 19.9999    ]), 'elecs': array([3, 2, 0, 3, 0, 2, 1, 2, 3]), 'action': array([4, 3, 1, 3, 0]), 'missed_cyc': 0, 'stim_id': 97, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 1 1 2 3]
# Info: {'spikes': array([ 5.69324113,  7.59772408,  7.60669444, 10.78515417, 12.52149739,
#        12.77902041, 13.32121414, 16.00114999, 19.18507464, 19.4387308 ,
#        19.9999    ]), 'elecs': array([1, 0, 2, 2, 1, 1, 0, 1, 2, 2, 3]), 'action': array([2, 1, 1, 2, 3]), 'missed_cyc': 0, 'stim_id': 98, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0 1 2 2]
# Info: {'spikes': array([ 4.17011012,  7.84810073, 11.81210728, 14.67848507, 15.14104782,
#        16.26428994, 19.63576863, 19.9999    , 19.9999    ]), 'elecs': array([1, 2, 0, 3, 1, 1, 1, 2, 2]), 'action': array([2, 0, 1, 2, 2]), 'missed_cyc': 0, 'stim_id': 99, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 3 3 2 1]
# Info: {'spikes': array([ 4.50243529,  7.84362896,  9.43208912, 11.29811411, 13.03965418,
#        15.13568145, 15.96473647, 19.73694868, 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 2, 2, 3, 1, 3, 0, 2, 1]), 'action': array([4, 3, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 100, 'simulated': True, 'comment': 'none'}
# -----------------------------

# %%
print(f"Average reward: {total_reward/action_count}")
# Out:
# Average reward: 1.38
