# %% [markdown]
# This jupyter gives you a simple example of how you should use the Simulated Network (asynchronous) environment. This environment is not meant as a training ground of your algorithms, but only to check whether or not your algorithm can be executed and if it is fast enough to create a response in time. (Set stim_period = 100 to be sure).

# %%
import gymnasium as gym
import numpy as np

# Add parent directory to path
import sys
from pathlib import Path
current_dir = Path().resolve()
root_dir = current_dir.parent
if str(root_dir) not in sys.path:
    sys.path.insert(0,str(root_dir))

from Gyms.SimulatedNetworkSync import SimulatedNetworkSync

# %%
# Define size of state and action spaces, as well as stimulation period
state_dim   = 4   # Dimension of reduced state space
action_dim  = 2   # Number of stimuli in action space. Must be less or equal to 5 (each stimulus needs a value of {0,1,2,3,4}
stim_period = 250 # stimulation period, meaning that an action is applied every {stim_period} ms

# %%
# Create environment and initialize it
env      = SimulatedNetworkSync(action_dim=action_dim,state_dim=state_dim,stim_period=stim_period)
state, _ = env.reset()
env.render() # This function gives you the current state + reward, which both is 0 after initialization
# Out:
# Current state: [0. 0. 0. 0.], Reward: 0

# %%
# Example code, that stimulates the network 100 times with a randomly sampled action, while calculating also the average reward received

total_reward = 0
action_count = 0

for _ in range(100):
    # For simplicity, choose a random action
    action = env.action_space.sample()
    print(f"Stimulate with action: {action}")
    
    state, reward, terminated, truncated, info = env.step(action)
    total_reward += reward
    action_count += 1

    # Plot information
    print(f"Info: {info}")

    print("-----------------------------")
# Out:
# Stimulate with action: [2 4]
# Info: {'spikes': array([ 1.35524882,  2.94762253,  6.02843802,  7.74934069, 10.87973413]), 'elecs': array([0, 1, 2, 3, 0]), 'action': array([2, 4]), 'missed_cyc': 0, 'stim_id': 1, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 0]
# Info: {'spikes': [], 'elecs': [], 'action': array([0, 0]), 'missed_cyc': 0, 'stim_id': 2, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 3]
# Info: {'spikes': array([ 3.6648715 ,  6.68863687,  6.77168744,  9.50673423, 12.44335497]), 'elecs': array([2, 3, 0, 2, 3]), 'action': array([3, 3]), 'missed_cyc': 0, 'stim_id': 3, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 4]
# Info: {'spikes': array([ 3.83403118,  7.01611731,  8.3241198 ,  9.82426319, 15.06320235]), 'elecs': array([3, 3, 0, 0, 1]), 'action': array([4, 4]), 'missed_cyc': 0, 'stim_id': 4, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 4]
# Info: {'spikes': array([ 5.80628534,  7.70001018,  8.46045768, 11.8238369 ]), 'elecs': array([2, 3, 3, 0]), 'action': array([3, 4]), 'missed_cyc': 0, 'stim_id': 5, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 3]
# Info: {'spikes': array([ 6.66736554, 11.47179526]), 'elecs': array([2, 3]), 'action': array([0, 3]), 'missed_cyc': 0, 'stim_id': 6, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 1]
# Info: {'spikes': array([ 4.68394983,  8.00890701,  8.20421736, 10.94827229]), 'elecs': array([1, 0, 2, 1]), 'action': array([2, 1]), 'missed_cyc': 0, 'stim_id': 7, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 2]
# Info: {'spikes': array([ 6.8760654 , 11.30087296]), 'elecs': array([1, 2]), 'action': array([0, 2]), 'missed_cyc': 0, 'stim_id': 8, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3]
# Info: {'spikes': array([ 2.751068  ,  6.13817853,  6.79188841, 10.54858933]), 'elecs': array([0, 2, 1, 3]), 'action': array([1, 3]), 'missed_cyc': 0, 'stim_id': 9, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2]
# Info: {'spikes': array([ 3.98037832,  7.24323547,  8.09577739, 12.71687385]), 'elecs': array([0, 1, 1, 2]), 'action': array([1, 2]), 'missed_cyc': 0, 'stim_id': 10, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1]
# Info: {'spikes': array([ 4.14113108,  6.04308497,  7.76541703, 11.92404741]), 'elecs': array([0, 1, 0, 1]), 'action': array([1, 1]), 'missed_cyc': 0, 'stim_id': 11, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 4]
# Info: {'spikes': array([ 4.90941495,  8.61502135,  8.921105  , 10.80306924]), 'elecs': array([2, 3, 3, 0]), 'action': array([3, 4]), 'missed_cyc': 0, 'stim_id': 12, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 0]
# Info: {'spikes': array([4.25464285, 7.48038704]), 'elecs': array([3, 0]), 'action': array([4, 0]), 'missed_cyc': 0, 'stim_id': 13, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 3]
# Info: {'spikes': array([ 1.96102355,  4.4517668 ,  7.97293596,  9.03681454, 12.18138755]), 'elecs': array([1, 1, 2, 2, 3]), 'action': array([2, 3]), 'missed_cyc': 0, 'stim_id': 14, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 4]
# Info: {'spikes': array([ 6.7629671 , 11.42711349]), 'elecs': array([3, 0]), 'action': array([0, 4]), 'missed_cyc': 0, 'stim_id': 15, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 2]
# Info: {'spikes': array([ 8.83965336, 12.43880462]), 'elecs': array([1, 2]), 'action': array([0, 2]), 'missed_cyc': 0, 'stim_id': 16, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 2]
# Info: {'spikes': array([ 9.66101571, 11.47668184]), 'elecs': array([1, 2]), 'action': array([0, 2]), 'missed_cyc': 0, 'stim_id': 17, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 3]
# Info: {'spikes': array([ 8.51581263, 11.72022051]), 'elecs': array([2, 3]), 'action': array([0, 3]), 'missed_cyc': 0, 'stim_id': 18, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 3]
# Info: {'spikes': array([ 6.16424328,  8.27472566,  9.01274088, 10.28956041]), 'elecs': array([2, 2, 3, 3]), 'action': array([3, 3]), 'missed_cyc': 0, 'stim_id': 19, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 1]
# Info: {'spikes': array([ 4.45196877,  7.67479425,  8.25073333, 12.36824448]), 'elecs': array([3, 0, 0, 1]), 'action': array([4, 1]), 'missed_cyc': 0, 'stim_id': 20, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 4]
# Info: {'spikes': array([ 3.28000612,  7.88667537,  8.5412113 , 12.72298079]), 'elecs': array([2, 3, 3, 0]), 'action': array([3, 4]), 'missed_cyc': 0, 'stim_id': 21, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 4]
# Info: {'spikes': array([ 3.50087476,  7.54880556,  8.56002743, 11.11750968]), 'elecs': array([0, 1, 3, 0]), 'action': array([1, 4]), 'missed_cyc': 0, 'stim_id': 22, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 1]
# Info: {'spikes': array([ 7.91150914, 11.14532375]), 'elecs': array([0, 1]), 'action': array([0, 1]), 'missed_cyc': 0, 'stim_id': 23, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 1]
# Info: {'spikes': array([ 6.8141504 , 11.64410526]), 'elecs': array([0, 1]), 'action': array([0, 1]), 'missed_cyc': 0, 'stim_id': 24, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3]
# Info: {'spikes': array([ 4.47658563,  4.64727688,  6.5782177 ,  7.51189536,  9.30440491,
#        11.30353269]), 'elecs': array([0, 0, 1, 2, 1, 3]), 'action': array([1, 3]), 'missed_cyc': 0, 'stim_id': 25, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 4]
# Info: {'spikes': array([ 2.78532566,  6.12302422,  8.43367017, 12.18199683]), 'elecs': array([1, 2, 3, 0]), 'action': array([2, 4]), 'missed_cyc': 0, 'stim_id': 26, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 4]
# Info: {'spikes': array([ 4.79444282,  8.6283305 ,  9.67962812, 12.90833272]), 'elecs': array([2, 3, 3, 0]), 'action': array([3, 4]), 'missed_cyc': 0, 'stim_id': 27, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 4]
# Info: {'spikes': array([ 5.30946457,  7.61993746,  8.7928213 , 13.77966755]), 'elecs': array([2, 3, 3, 0]), 'action': array([3, 4]), 'missed_cyc': 0, 'stim_id': 28, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0]
# Info: {'spikes': array([4.70308595, 7.32305541]), 'elecs': array([1, 2]), 'action': array([2, 0]), 'missed_cyc': 0, 'stim_id': 29, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 2]
# Info: {'spikes': array([ 0.23832632,  3.16420611,  6.59834375,  7.42780269, 12.25153276]), 'elecs': array([1, 3, 1, 0, 2]), 'action': array([4, 2]), 'missed_cyc': 0, 'stim_id': 30, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0]
# Info: {'spikes': array([ 4.62157043, 10.69047622]), 'elecs': array([1, 2]), 'action': array([2, 0]), 'missed_cyc': 0, 'stim_id': 31, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 2]
# Info: {'spikes': array([ 7.91411725, 12.39801932, 12.59700219]), 'elecs': array([1, 1, 2]), 'action': array([0, 2]), 'missed_cyc': 0, 'stim_id': 32, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 4]
# Info: {'spikes': array([ 3.4538168 ,  6.74490774,  8.49160997, 11.3678924 , 18.54766471]), 'elecs': array([0, 1, 3, 0, 1]), 'action': array([1, 4]), 'missed_cyc': 0, 'stim_id': 33, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3]
# Info: {'spikes': array([ 0.82799701,  5.10465676,  7.0559987 ,  8.14309633, 12.41046239]), 'elecs': array([1, 0, 1, 2, 3]), 'action': array([1, 3]), 'missed_cyc': 0, 'stim_id': 34, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 0]
# Info: {'spikes': array([2.87560954, 9.00299577, 9.11613691]), 'elecs': array([0, 1, 1]), 'action': array([1, 0]), 'missed_cyc': 0, 'stim_id': 35, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 4]
# Info: {'spikes': array([ 7.2160545 , 11.14479862]), 'elecs': array([3, 0]), 'action': array([0, 4]), 'missed_cyc': 0, 'stim_id': 36, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 3]
# Info: {'spikes': array([ 3.54825816,  7.30508826,  8.20741746, 11.82323526]), 'elecs': array([3, 2, 0, 3]), 'action': array([4, 3]), 'missed_cyc': 0, 'stim_id': 37, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 0]
# Info: {'spikes': array([10.393802]), 'elecs': array([1]), 'action': array([0, 0]), 'missed_cyc': 0, 'stim_id': 38, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2]
# Info: {'spikes': array([ 3.3566301 ,  8.78767103,  9.10024837, 13.35874591]), 'elecs': array([0, 1, 1, 2]), 'action': array([1, 2]), 'missed_cyc': 0, 'stim_id': 39, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1]
# Info: {'spikes': array([ 4.84276548,  8.4926072 ,  9.1329728 , 12.40664378, 12.91920114]), 'elecs': array([0, 1, 0, 1, 1]), 'action': array([1, 1]), 'missed_cyc': 0, 'stim_id': 40, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 3]
# Info: {'spikes': array([ 3.07939371,  7.97950663,  8.4659121 , 11.91708685]), 'elecs': array([3, 0, 2, 3]), 'action': array([4, 3]), 'missed_cyc': 0, 'stim_id': 41, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3]
# Info: {'spikes': array([ 4.82803939,  7.75878928,  8.423207  , 13.42464158]), 'elecs': array([0, 2, 1, 3]), 'action': array([1, 3]), 'missed_cyc': 0, 'stim_id': 42, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2]
# Info: {'spikes': array([ 3.08392617,  6.49989911,  8.17972652, 11.64098552]), 'elecs': array([0, 1, 1, 2]), 'action': array([1, 2]), 'missed_cyc': 0, 'stim_id': 43, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 4]
# Info: {'spikes': array([ 3.84502153,  7.0731315 ,  7.4204123 , 11.5097948 ]), 'elecs': array([3, 0, 3, 0]), 'action': array([4, 4]), 'missed_cyc': 0, 'stim_id': 44, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 3]
# Info: {'spikes': array([ 4.15032282,  6.68911956,  6.9894228 , 12.28289999]), 'elecs': array([1, 2, 2, 3]), 'action': array([2, 3]), 'missed_cyc': 0, 'stim_id': 45, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 0]
# Info: {'spikes': array([4.14712532, 6.9969408 ]), 'elecs': array([2, 3]), 'action': array([3, 0]), 'missed_cyc': 0, 'stim_id': 46, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 1]
# Info: {'spikes': array([ 3.90640679,  7.35266231,  7.62947633, 12.23276434, 16.22299807]), 'elecs': array([2, 0, 3, 1, 1]), 'action': array([3, 1]), 'missed_cyc': 0, 'stim_id': 47, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 0]
# Info: {'spikes': array([1.21754523, 3.55068582, 6.51874374]), 'elecs': array([1, 2, 3]), 'action': array([3, 0]), 'missed_cyc': 0, 'stim_id': 48, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 2]
# Info: {'spikes': array([ 6.98229399,  8.86883443, 12.78823972]), 'elecs': array([1, 1, 2]), 'action': array([0, 2]), 'missed_cyc': 0, 'stim_id': 49, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 2]
# Info: {'spikes': array([ 4.83455821,  7.4229157 ,  9.48624183, 12.84210616]), 'elecs': array([1, 1, 2, 2]), 'action': array([2, 2]), 'missed_cyc': 0, 'stim_id': 50, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2]
# Info: {'spikes': array([ 3.00516671,  6.68863324,  7.37999282, 12.62370626]), 'elecs': array([0, 1, 1, 2]), 'action': array([1, 2]), 'missed_cyc': 0, 'stim_id': 51, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 0]
# Info: {'spikes': array([1.85425532, 7.5456594 ]), 'elecs': array([0, 1]), 'action': array([1, 0]), 'missed_cyc': 0, 'stim_id': 52, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1]
# Info: {'spikes': array([ 3.0744595 ,  7.39760815,  7.9673398 , 12.61801187]), 'elecs': array([0, 1, 0, 1]), 'action': array([1, 1]), 'missed_cyc': 0, 'stim_id': 53, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 4]
# Info: {'spikes': array([ 3.17749694,  7.33955525,  8.04982004, 11.46771276]), 'elecs': array([3, 3, 0, 0]), 'action': array([4, 4]), 'missed_cyc': 0, 'stim_id': 54, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 4]
# Info: {'spikes': array([ 3.45766575,  5.38098949,  7.35061412,  8.17121626, 11.46080225]), 'elecs': array([0, 0, 3, 1, 0]), 'action': array([1, 4]), 'missed_cyc': 0, 'stim_id': 55, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0]
# Info: {'spikes': array([5.08669818, 9.37821197]), 'elecs': array([1, 2]), 'action': array([2, 0]), 'missed_cyc': 0, 'stim_id': 56, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 4]
# Info: {'spikes': array([ 4.04644521,  6.08607743,  8.54594586,  8.87382509, 11.04415472]), 'elecs': array([1, 2, 3, 3, 0]), 'action': array([3, 4]), 'missed_cyc': 0, 'stim_id': 57, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 3]
# Info: {'spikes': array([ 3.69685719,  8.24431188,  8.49678705, 12.05610469]), 'elecs': array([1, 2, 2, 3]), 'action': array([2, 3]), 'missed_cyc': 0, 'stim_id': 58, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 1]
# Info: {'spikes': array([ 2.90971743,  8.01298191,  8.58014041, 12.64312146]), 'elecs': array([1, 0, 2, 1]), 'action': array([2, 1]), 'missed_cyc': 0, 'stim_id': 59, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 2]
# Info: {'spikes': array([ 5.36327624, 11.47477868]), 'elecs': array([1, 2]), 'action': array([0, 2]), 'missed_cyc': 0, 'stim_id': 60, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 4]
# Info: {'spikes': array([ 1.54091882,  6.87085719,  9.72414675, 10.18488711]), 'elecs': array([3, 3, 0, 0]), 'action': array([4, 4]), 'missed_cyc': 0, 'stim_id': 61, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 4]
# Info: {'spikes': array([ 4.97770181,  7.20297078,  7.73311417, 10.45854977]), 'elecs': array([1, 2, 3, 0]), 'action': array([2, 4]), 'missed_cyc': 0, 'stim_id': 62, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 0]
# Info: {'spikes': array([3.12886647, 8.30762574]), 'elecs': array([0, 1]), 'action': array([1, 0]), 'missed_cyc': 0, 'stim_id': 63, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1]
# Info: {'spikes': array([ 4.71284601,  7.59108181,  8.21676462, 11.33332277]), 'elecs': array([0, 1, 0, 1]), 'action': array([1, 1]), 'missed_cyc': 0, 'stim_id': 64, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2]
# Info: {'spikes': array([ 2.97574271,  6.64916234,  6.9967763 , 12.79920579]), 'elecs': array([0, 1, 1, 2]), 'action': array([1, 2]), 'missed_cyc': 0, 'stim_id': 65, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 2]
# Info: {'spikes': array([ 4.5334821 ,  6.80234261,  7.76173463, 12.62634266]), 'elecs': array([3, 1, 0, 2]), 'action': array([4, 2]), 'missed_cyc': 0, 'stim_id': 66, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 3]
# Info: {'spikes': array([ 4.42440359,  6.6333536 ,  7.73005263, 12.84050956]), 'elecs': array([3, 0, 2, 3]), 'action': array([4, 3]), 'missed_cyc': 0, 'stim_id': 67, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 4]
# Info: {'spikes': array([ 2.37913731,  8.56851457,  8.88680451, 11.63063125]), 'elecs': array([1, 2, 3, 0]), 'action': array([2, 4]), 'missed_cyc': 0, 'stim_id': 68, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 0]
# Info: {'spikes': array([2.90364521, 9.35735379]), 'elecs': array([3, 0]), 'action': array([4, 0]), 'missed_cyc': 0, 'stim_id': 69, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 0]
# Info: {'spikes': array([1.97806984, 9.72513902]), 'elecs': array([2, 3]), 'action': array([3, 0]), 'missed_cyc': 0, 'stim_id': 70, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 4]
# Info: {'spikes': array([ 5.18810381,  7.83919284, 11.57100468]), 'elecs': array([0, 3, 0]), 'action': array([0, 4]), 'missed_cyc': 0, 'stim_id': 71, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 0]
# Info: {'spikes': array([15.26799973]), 'elecs': array([1]), 'action': array([0, 0]), 'missed_cyc': 0, 'stim_id': 72, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 0]
# Info: {'spikes': array([4.4628209 , 8.49616293]), 'elecs': array([0, 1]), 'action': array([1, 0]), 'missed_cyc': 0, 'stim_id': 73, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3]
# Info: {'spikes': array([ 3.05610497,  7.28098271,  8.64084788, 11.23432891]), 'elecs': array([0, 1, 2, 3]), 'action': array([1, 3]), 'missed_cyc': 0, 'stim_id': 74, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 4]
# Info: {'spikes': array([ 3.77338347,  7.55250345,  9.7239549 , 10.41529238]), 'elecs': array([1, 3, 2, 0]), 'action': array([2, 4]), 'missed_cyc': 0, 'stim_id': 75, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 3]
# Info: {'spikes': array([ 4.23661467,  6.92657367,  7.35137853,  8.12750695, 12.01723033]), 'elecs': array([1, 2, 2, 1, 3]), 'action': array([2, 3]), 'missed_cyc': 0, 'stim_id': 76, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 4]
# Info: {'spikes': array([ 4.72362196,  8.02331197,  8.06838017, 13.69811043]), 'elecs': array([2, 3, 3, 0]), 'action': array([3, 4]), 'missed_cyc': 0, 'stim_id': 77, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 1]
# Info: {'spikes': array([ 4.22249541,  7.03293543,  7.78269947, 12.93565849]), 'elecs': array([3, 0, 0, 1]), 'action': array([4, 1]), 'missed_cyc': 0, 'stim_id': 78, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 4]
# Info: {'spikes': array([ 1.42108233,  6.96100307,  8.27786257, 10.18792924]), 'elecs': array([2, 3, 3, 0]), 'action': array([3, 4]), 'missed_cyc': 0, 'stim_id': 79, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 2]
# Info: {'spikes': array([ 2.18726896,  7.63648977,  8.59049742, 11.42496885]), 'elecs': array([2, 3, 1, 2]), 'action': array([3, 2]), 'missed_cyc': 0, 'stim_id': 80, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 0]
# Info: {'spikes': array([1.07346439, 3.76434591, 7.63545473]), 'elecs': array([1, 3, 0]), 'action': array([4, 0]), 'missed_cyc': 0, 'stim_id': 81, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 4]
# Info: {'spikes': array([ 7.04003425, 12.70941203, 13.7617879 ]), 'elecs': array([3, 0, 0]), 'action': array([0, 4]), 'missed_cyc': 0, 'stim_id': 82, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3]
# Info: {'spikes': array([ 4.72566237,  8.42690657,  8.80354867, 11.60535573]), 'elecs': array([0, 2, 1, 3]), 'action': array([1, 3]), 'missed_cyc': 0, 'stim_id': 83, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 4]
# Info: {'spikes': array([ 2.69863857,  6.39894326,  7.36087173, 10.94634381]), 'elecs': array([1, 2, 3, 0]), 'action': array([2, 4]), 'missed_cyc': 0, 'stim_id': 84, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2]
# Info: {'spikes': array([ 2.16489236,  8.65904231,  9.33413036, 13.46204318]), 'elecs': array([0, 1, 1, 2]), 'action': array([1, 2]), 'missed_cyc': 0, 'stim_id': 85, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 4]
# Info: {'spikes': array([3.73911631, 7.93937202, 8.48979345, 9.54849273]), 'elecs': array([0, 1, 3, 0]), 'action': array([1, 4]), 'missed_cyc': 0, 'stim_id': 86, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 3]
# Info: {'spikes': array([ 3.49562262,  8.06692557,  8.3668582 , 10.99078464]), 'elecs': array([1, 2, 2, 3]), 'action': array([2, 3]), 'missed_cyc': 0, 'stim_id': 87, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 1]
# Info: {'spikes': array([ 4.65075024,  7.61888253,  8.10819055, 13.89528502]), 'elecs': array([3, 0, 0, 1]), 'action': array([4, 1]), 'missed_cyc': 0, 'stim_id': 88, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 1]
# Info: {'spikes': array([ 4.52109433,  4.64400048,  6.30473999,  8.72285715, 11.96167269]), 'elecs': array([0, 2, 0, 3, 1]), 'action': array([3, 1]), 'missed_cyc': 0, 'stim_id': 89, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 1]
# Info: {'spikes': array([ 6.46758829, 10.30290035]), 'elecs': array([0, 1]), 'action': array([0, 1]), 'missed_cyc': 0, 'stim_id': 90, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 4]
# Info: {'spikes': array([ 4.46041472,  7.86066065,  8.20356871, 11.594895  ]), 'elecs': array([0, 1, 3, 0]), 'action': array([1, 4]), 'missed_cyc': 0, 'stim_id': 91, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 1]
# Info: {'spikes': array([ 4.50341321,  6.4683443 ,  7.30931716,  8.74987462, 11.63082319]), 'elecs': array([1, 0, 2, 1, 1]), 'action': array([2, 1]), 'missed_cyc': 0, 'stim_id': 92, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 3]
# Info: {'spikes': array([ 3.54871607,  7.04267085,  7.0429312 , 11.5289889 ]), 'elecs': array([1, 2, 2, 3]), 'action': array([2, 3]), 'missed_cyc': 0, 'stim_id': 93, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0]
# Info: {'spikes': array([4.14887845, 6.59795116]), 'elecs': array([1, 2]), 'action': array([2, 0]), 'missed_cyc': 0, 'stim_id': 94, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 0]
# Info: {'spikes': array([3.73825472, 6.89124789]), 'elecs': array([0, 1]), 'action': array([1, 0]), 'missed_cyc': 0, 'stim_id': 95, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 1]
# Info: {'spikes': array([ 6.06526417,  7.49298267,  7.75279765,  9.48016674, 11.4638971 ]), 'elecs': array([1, 0, 2, 1, 1]), 'action': array([2, 1]), 'missed_cyc': 0, 'stim_id': 96, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 0]
# Info: {'spikes': array([4.40882751, 8.48450901]), 'elecs': array([3, 0]), 'action': array([4, 0]), 'missed_cyc': 0, 'stim_id': 97, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 2]
# Info: {'spikes': array([10.30112992, 11.20048124]), 'elecs': array([1, 2]), 'action': array([0, 2]), 'missed_cyc': 0, 'stim_id': 98, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 1]
# Info: {'spikes': array([ 2.9201932 ,  6.86969853,  8.88673643, 10.9658795 ]), 'elecs': array([3, 0, 0, 1]), 'action': array([4, 1]), 'missed_cyc': 0, 'stim_id': 99, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 3]
# Info: {'spikes': array([ 3.13071275,  7.66852401,  8.21962417, 11.62761908]), 'elecs': array([1, 2, 2, 3]), 'action': array([2, 3]), 'missed_cyc': 0, 'stim_id': 100, 'simulated': True, 'comment': 'none'}
# -----------------------------

# %%
print(f"Average reward: {total_reward/action_count}")
# Out:
# Average reward: 0.39
