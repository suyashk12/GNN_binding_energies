# %% [markdown]
# This jupyter gives you a simple example of how you should use the Simulated Network (asynchronous) environment. This environment is not meant as a training ground of your algorithms, but only to check whether or not your algorithm can be executed and if it is fast enough to create a response in time. (Set stim_period = 100 to be sure).

# %%
import gymnasium as gym
import numpy as np

# Add parent directory to path
import sys
from pathlib import Path
current_dir = Path().resolve()
root_dir = current_dir.parent
if str(root_dir) not in sys.path:
    sys.path.insert(0,str(root_dir))

from Gyms.SimulatedNetworkSync import SimulatedNetworkSync

# %%
# Define size of state and action spaces, as well as stimulation period
state_dim   = 4   # Dimension of reduced state space
action_dim  = 2   # Number of stimuli in action space (each stimulus needs a value of {0,1,2,3,4}
stim_period = 250 # stimulation period, meaning that an action is applied every {stim_period} ms

# %%
# Create environment and initialize it
env      = SimulatedNetworkSync(action_dim=action_dim,state_dim=state_dim,stim_period=stim_period)
state, _ = env.reset()
env.render() # This function gives you the current state + reward, which both is 0 after initialization
# Out:
# Current state: [0. 0. 0. 0.], Reward: 0

# %%
# Example code, that stimulates the network 100 times with a randomly sampled action, while calculating also the average reward received

total_reward = 0
action_count = 0

for _ in range(100):
    # For simplicity, choose a random action
    action = env.action_space.sample()
    print(f"Stimulate with action: {action}")
    
    state, reward, terminated, truncated, info = env.step(action)
    total_reward += reward
    action_count += 1

    # Plot information
    print(f"Info: {info}")

    print("-----------------------------")
# Out:
# Stimulate with action: [0 0]
# Info: {'spikes': [], 'elecs': [], 'missed_cyc': 0, 'stim_id': 1, 'simulated': True}
# -----------------------------
# Stimulate with action: [2 3]
# Info: {'spikes': array([ 4.16442173,  6.33305201,  9.52559743, 11.85604547]), 'elecs': array([1, 2, 2, 3]), 'missed_cyc': 0, 'stim_id': 2, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 3]
# Info: {'spikes': array([ 3.94076413,  6.15538931,  7.4413709 , 10.48690574]), 'elecs': array([0, 2, 1, 3]), 'missed_cyc': 0, 'stim_id': 3, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 1]
# Info: {'spikes': array([ 4.10737605,  8.91682987,  9.25274852, 12.20118058]), 'elecs': array([0, 1, 0, 1]), 'missed_cyc': 0, 'stim_id': 4, 'simulated': True}
# -----------------------------
# Stimulate with action: [4 1]
# Info: {'spikes': array([ 4.22592038,  6.43552834,  6.80693322, 10.90468064, 12.26139242]), 'elecs': array([3, 0, 0, 1, 1]), 'missed_cyc': 0, 'stim_id': 5, 'simulated': True}
# -----------------------------
# Stimulate with action: [0 0]
# Info: {'spikes': [], 'elecs': [], 'missed_cyc': 0, 'stim_id': 6, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 4]
# Info: {'spikes': array([ 0.79836394,  4.78288938,  7.92661158,  8.60189714, 12.62005771]), 'elecs': array([1, 0, 3, 1, 0]), 'missed_cyc': 0, 'stim_id': 7, 'simulated': True}
# -----------------------------
# Stimulate with action: [2 2]
# Info: {'spikes': array([ 3.02063749,  7.78127083,  8.91543824,  9.29887674, 11.78286028]), 'elecs': array([1, 1, 2, 1, 2]), 'missed_cyc': 0, 'stim_id': 8, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 0]
# Info: {'spikes': array([4.58070391, 8.87644256]), 'elecs': array([0, 1]), 'missed_cyc': 0, 'stim_id': 9, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 1]
# Info: {'spikes': array([ 0.58479891,  7.63559031,  9.59364629, 12.05840967]), 'elecs': array([0, 1, 0, 1]), 'missed_cyc': 0, 'stim_id': 10, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 2]
# Info: {'spikes': array([ 5.34523203,  7.13163438,  7.60470475, 12.3645461 ]), 'elecs': array([0, 1, 1, 2]), 'missed_cyc': 0, 'stim_id': 11, 'simulated': True}
# -----------------------------
# Stimulate with action: [0 3]
# Info: {'spikes': array([ 7.29238735,  9.63060415, 13.64702469]), 'elecs': array([2, 3, 0]), 'missed_cyc': 0, 'stim_id': 12, 'simulated': True}
# -----------------------------
# Stimulate with action: [3 0]
# Info: {'spikes': array
 'simulated': True}
# -----------------------------
# Stimulate with action: [3 1]
# Info: {'spikes': array([ 5.61102526,  9.11084508,  9.78687378, 11.03100565]), 'elecs': array([2, 0, 3, 1]), 'missed_cyc': 0, 'stim_id': 58, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 3]
# Info: {'spikes': array([ 4.51270537,  7.14182924,  8.24958318, 11.01567628]), 'elecs': array([0, 1, 2, 3]), 'missed_cyc': 0, 'stim_id': 59, 'simulated': True}
# -----------------------------
# Stimulate with action: [0 3]
# Info: {'spikes': array([ 8.37059552, 12.92863649]), 'elecs': array([2, 3]), 'missed_cyc': 0, 'stim_id': 60, 'simulated': True}
# -----------------------------
# Stimulate with action: [2 0]
# Info: {'spikes': array([2.13509542, 7.88945504]), 'elecs': array([1, 2]), 'missed_cyc': 0, 'stim_id': 61, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 4]
# Info: {'spikes': array([ 2.01605122,  7.58361733,  9.51892884, 10.09131831]), 'elecs': array([0, 3, 0, 1]), 'missed_cyc': 0, 'stim_id': 62, 'simulated': True}
# -----------------------------
# Stimulate with action: [0 4]
# Info: {'spikes': array([ 3.26983141,  7.55134173, 12.92203893]), 'elecs': array([1, 3, 0]), 'missed_cyc': 0, 'stim_id': 63, 'simulated': True}
# -----------------------------
# Stimulate with action: [3 3]
# Info: {'spikes': array([ 3.7315424 ,  6.70657112,  7.48814875, 10.15701233]), 'elecs': array([2, 2, 3, 3]), 'missed_cyc': 0, 'stim_id': 64, 'simulated': True}
# -----------------------------
# Stimulate with action: [0 0]
# Info: {'spikes': array([ 2.14962893, 17.66376055]), 'elecs': array([0, 1]), 'missed_cyc': 0, 'stim_id': 65, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 1]
# Info: {'spikes': array([ 4.84602231,  7.26909894,  9.81551651, 12.98941953]), 'elecs': array([0, 1, 0, 1]), 'missed_cyc': 0, 'stim_id': 66, 'simulated': True}
# -----------------------------
# Stimulate with action: [4 2]
# Info: {'spikes': array([ 5.11332117,  7.27119313,  8.65490565, 11.32423263]), 'elecs': array([3, 1, 0, 2]), 'missed_cyc': 0, 'stim_id': 67, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 2]
# Info: {'spikes': array([ 6.51324345,  7.46380172,  7.80369503, 13.34200498]), 'elecs': array([0, 1, 1, 2]), 'missed_cyc': 0, 'stim_id': 68, 'simulated': True}
# -----------------------------
# Stimulate with action: [0 4]
# Info: {'spikes': array([ 7.69816261, 10.48581812]), 'elecs': array([3, 0]), 'missed_cyc': 0, 'stim_id': 69, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 2]
# Info: {'spikes': array([ 0.70680527,  3.94355919,  7.40194669,  7.63379321, 11.17496662]), 'elecs': array([1, 0, 1, 1, 2]), 'missed_cyc': 0, 'stim_id': 70, 'simulated': True}
# -----------------------------
# Stimulate with action: [2 3]
# Info: {'spikes': array([ 2.30454811,  7.37166744,  8.09834441, 12.04257534]), 'elecs': array([1, 2, 2, 3]), 'missed_cyc': 0, 'stim_id': 71, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 2]
# Info: {'spikes': array([ 4.38621362,  6.23229818,  6.93490801, 13.35943055]), 'elecs': array([0, 1, 1, 2]), 'missed_cyc': 0, 'stim_id': 72, 'simulated': True}
# -----------------------------
# Stimulate with action: [0 3]
# Info: {'spikes': array([ 7.07439038,  7.79745192, 14.04686013]), 'elecs': array([1, 2, 3]), 'missed_cyc': 0, 'stim_id': 73, 'simulated': True}
# -----------------------------
# Stimulate with action: [3 1]
# Info: {'spikes': array([ 4.13805487,  7.25413175,  8.38623221, 10.11423644]), 'elecs': array([2, 0, 3, 1]), 'missed_cyc': 0, 'stim_id': 74, 'simulated': True}
# -----------------------------
# Stimulate with action: [4 0]
# Info: {'spikes': array([5.71075313, 7.5868987 ]), 'elecs': array([3, 0]), 'missed_cyc': 0, 'stim_id': 75, 'simulated': True}
# -----------------------------
# Stimulate with action: [0 1]
# Info: {'spikes': array([ 6.46138179, 12.80207512]), 'elecs': array([0, 1]), 'missed_cyc': 0, 'stim_id': 76, 'simulated': True}
# -----------------------------
# Stimulate with action: [4 4]
# Info: {'spikes': array([ 5.17061736,  8.50338007,  8.77801948, 13.75301402]), 'elecs': array([3, 3, 0, 0]), 'missed_cyc': 0, 'stim_id': 77, 'simulated': True}
# -----------------------------
# Stimulate with action: [3 3]
# Info: {'spikes': array([4.43911481, 4.64818125, 8.44377707, 9.19704241, 9.61549033]), 'elecs': array([2, 1, 2, 3, 3]), 'missed_cyc': 0, 'stim_id': 78, 'simulated': True}
# -----------------------------
# Stimulate with action: [0 3]
# Info: {'spikes': array([ 8.07835188, 12.18718138]), 'elecs': array([2, 3]), 'missed_cyc': 0, 'stim_id': 79, 'simulated': True}
# -----------------------------
# Stimulate with action: [2 1]
# Info: {'spikes': array([ 2.52052912,  7.21842919,  7.73024364, 12.94064861, 13.11234655]), 'elecs': array([1, 2, 0, 1, 1]), 'missed_cyc': 0, 'stim_id': 80, 'simulated': True}
# -----------------------------
# Stimulate with action: [4 2]
# Info: {'spikes': array([ 2.90346415,  7.65102516,  8.44253316, 10.47690552]), 'elecs': array([3, 0, 1, 2]), 'missed_cyc': 0, 'stim_id': 81, 'simulated': True}
# -----------------------------
# Stimulate with action: [3 4]
# Info: {'spikes': array([ 3.25450067,  8.08644556,  8.09810917, 12.59759837]), 'elecs': array([2, 3, 3, 0]), 'missed_cyc': 0, 'stim_id': 82, 'simulated': True}
# -----------------------------
# Stimulate with action: [2 1]
# Info: {'spikes': array([ 4.21402642,  7.53540878, 10.00232043, 11.6419033 ]), 'elecs': array([1, 2, 0, 1]), 'missed_cyc': 0, 'stim_id': 83, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 1]
# Info: {'spikes': array([ 3.2193299 ,  6.86947233, 10.14487987, 11.19309005]), 'elecs': array([0, 1, 0, 1]), 'missed_cyc': 0, 'stim_id': 84, 'simulated': True}
# -----------------------------
# Stimulate with action: [3 2]
# Info: {'spikes': array([ 4.21510752,  7.72870672,  8.3730828 , 13.09838066]), 'elecs': array([2, 1, 3, 2]), 'missed_cyc': 0, 'stim_id': 85, 'simulated': True}
# -----------------------------
# Stimulate with action: [2 3]
# Info: {'spikes': array([ 4.83042224,  6.77211043,  7.23742465, 12.81571304]), 'elecs': array([1, 2, 2, 3]), 'missed_cyc': 0, 'stim_id': 86, 'simulated': True}
# -----------------------------
# Stimulate with action: [0 3]
# Info: {'spikes': array([ 7.75140954, 11.0053907 ]), 'elecs': array([2, 3]), 'missed_cyc': 0, 'stim_id': 87, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 4]
# Info: {'spikes': array([ 3.45093183,  5.68562976,  6.84870029,  9.19552017, 13.02209421]), 'elecs': array([0, 0, 3, 1, 0]), 'missed_cyc': 0, 'stim_id': 88, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 4]
# Info: {'spikes': array([ 4.69169049,  6.51732848,  8.92780271, 13.93822873, 19.35986684]), 'elecs': array([0, 1, 3, 0, 1]), 'missed_cyc': 0, 'stim_id': 89, 'simulated': True}
# -----------------------------
# Stimulate with action: [4 4]
# Info: {'spikes': array([ 3.15975056,  6.3884408 , 10.20053622, 10.83079465]), 'elecs': array([3, 0, 3, 0]), 'missed_cyc': 0, 'stim_id': 90, 'simulated': True}
# -----------------------------
# Stimulate with action: [0 3]
# Info: {'spikes': array([ 6.59090052,  8.13733131, 11.45741098]), 'elecs': array([0, 2, 3]), 'missed_cyc': 0, 'stim_id': 91, 'simulated': True}
# -----------------------------
# Stimulate with action: [2 0]
# Info: {'spikes': array([4.5460336 , 8.6605185 , 8.80903458]), 'elecs': array([1, 2, 1]), 'missed_cyc': 0, 'stim_id': 92, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 0]
# Info: {'spikes': array([3.50941938, 7.42570197]), 'elecs': array([0, 1]), 'missed_cyc': 0, 'stim_id': 93, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 2]
# Info: {'spikes': array([ 4.186231  ,  6.15250298,  8.16963886, 13.52207263]), 'elecs': array([0, 1, 1, 2]), 'missed_cyc': 0, 'stim_id': 94, 'simulated': True}
# -----------------------------
# Stimulate with action: [3 0]
# Info: {'spikes': array([2.29752962, 5.48720831, 8.65672967]), 'elecs': array([0, 2, 3]), 'missed_cyc': 0, 'stim_id': 95, 'simulated': True}
# -----------------------------
# Stimulate with action: [3 4]
# Info: {'spikes': array([ 2.79007668,  5.02681606,  7.15252557,  9.19087829, 12.34297709]), 'elecs': array([2, 0, 3, 3, 0]), 'missed_cyc': 0, 'stim_id': 96, 'simulated': True}
# -----------------------------
# Stimulate with action: [4 4]
# Info: {'spikes': array([ 4.93205719,  6.75543437,  8.2747592 , 12.16645434]), 'elecs': array([3, 0, 3, 0]), 'missed_cyc': 0, 'stim_id': 97, 'simulated': True}
# -----------------------------
# Stimulate with action: [3 3]
# Info: {'spikes': array([ 3.0034851 ,  7.65389175,  7.97237628, 11.22557376, 11.56476391]), 'elecs': array([2, 3, 2, 3, 0]), 'missed_cyc': 0, 'stim_id': 98, 'simulated': True}
# -----------------------------
# Stimulate with action: [1 1]
# Info: {'spikes': array([ 4.3772692 ,  7.8796546 , 10.01776154, 12.28667915]), 'elecs': array([0, 0, 1, 1]), 'missed_cyc': 0, 'stim_id': 99, 'simulated': True}
# -----------------------------
# Stimulate with action: [4 1]
# Info: {'spikes': array([ 2.74031582,  5.8161823 ,  8.56368594, 10.5158365 , 12.96353721]), 'elecs': array([3, 0, 0, 0, 1]), 'missed_cyc': 0, 'stim_id': 100, 'simulated': True}
# -----------------------------
