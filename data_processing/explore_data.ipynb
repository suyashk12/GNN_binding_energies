# %%
import networkx as nx
import helper

train_data = helper.load_data_from_file("graph_data.json") # dictionary of SMILES and values are graphs

graph = train_data["C[CH2-].C[CH2-].[Zn+2]"]

# %%
graph

# %%
train_data
# Out:
# {'[Ag]': <networkx.classes.graph.Graph at 0x7f3708100fa0>,
#  'C/C(=C\\C(=O)C(F)(F)F)/O[Al](O/C(=C\\C(=O)C(F)(F)F)/C)O/C(=C\\C(=O)C(F)(F)F)/C': <networkx.classes.graph.Graph at 0x7f3708100d00>,
#  'C(=C(\\O[Al](O/C(=C\\C(=O)C(F)(F)F)/C(F)(F)F)O/C(=C\\C(=O)C(F)(F)F)/C(F)(F)F)/C(F)(F)F)\\C(=O)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f3708100580>,
#  'C/C(=C/C(=O)C)/O[Al](O/C(=C\\C(=O)C)/C)O/C(=C\\C(=O)C)/C': <networkx.classes.graph.Graph at 0x7f3708100ca0>,
#  'CC(/C(=C/C(=O)C(C)(C)C)/O[Al](O/C(=C\\C(=O)C(C)(C)C)/C(C)(C)C)O/C(=C\\C(=O)C(C)(C)C)/C(C)(C)C)(C)C': <networkx.classes.graph.Graph at 0x7f37081001f0>,
#  '[Ar]': <networkx.classes.graph.Graph at 0x7f3708100b80>,
#  '[As]12[As]3[As]1[As]23': <networkx.classes.graph.Graph at 0x7f3708100d60>,
#  '[AsH3]': <networkx.classes.graph.Graph at 0x7f3708100340>,
#  'C[As](C)C': <networkx.classes.graph.Graph at 0x7f3708101360>,
#  'C1=CC=[As]C=C1': <networkx.classes.graph.Graph at 0x7f370020dc60>,
#  'F[As](F)F': <networkx.classes.graph.Graph at 0x7f370020fd90>,
#  'F[As](F)(F)(F)F': <networkx.classes.graph.Graph at 0x7f370020f610>,
#  'B(Br)(Br)Br': <networkx.classes.graph.Graph at 0x7f370020f8b0>,
#  'B.[C-]#[O+]': <networkx.classes.graph.Graph at 0x7f370020f910>,
#  'B(C)(C)C': <networkx.classes.graph.Graph at 0x7f370020fcd0>,
#  'B(OC)(OC)OC': <networkx.classes.graph.Graph at 0x7f370020fdf0>,
#  'B.CN(C)C': <networkx.classes.graph.Graph at 0x7f370020fee0>,
#  '[BH3-][P+](C)(C)C': <networkx.classes.graph.Graph at 0x7f370020ffd0>,
#  'B(CC)(CC)Cl': <networkx.classes.graph.Graph at 0x7f370020f070>,
#  'BN(CC)CC': <networkx.classes.graph.Graph at 0x7f370020f4f0>,
#  'B(CC)(CC)CC': <networkx.classes.graph.Graph at 0x7f3708282ec0>,
#  'B(OCC)(OCC)OCC': <networkx.classes.graph.Graph at 0x7f37007aabc0>,
#  '[BH3-][N+](CC)(CC)CC': <networkx.classes.graph.Graph at 0x7f36eb4f4670>,
#  'B1(C2=C(C=CS2)C=NN1C)C': <networkx.classes.graph.Graph at 0x7f36eb4f46d0>,
#  '[B-](C)(C)(C)C#[N+]C(C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb4f4730>,
#  'B(Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f4790>,
#  'B(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f47f0>,
#  'B(I)(I)I': <networkx.classes.graph.Graph at 0x7f36eb4f4850>,
#  'C[N+]1(C)[BH2-][H][BH2-]1': <networkx.classes.graph.Graph at 0x7f36eb4f48b0>,
#  'B(B(N(C)C)N(C)C)(N(C)C)N(C)C': <networkx.classes.graph.Graph at 0x7f36eb4f4910>,
#  'B(CC)(CC)CC.B(CC)(CC)CC': <networkx.classes.graph.Graph at 0x7f36eb4f5570>,
#  '[BH2]1[H][BH2][H]1': <networkx.classes.graph.Graph at 0x7f36eb4f55d0>,
#  'B1C2BC1B2': <networkx.classes.graph.Graph at 0x7f36eb4f5630>,
#  'B1(C2(B(C1(B2CC)CC)CC)CC)CC': <networkx.classes.graph.Graph at 0x7f36eb4f5510>,
#  '[BH]123[BH]45[BH]67[BH]1([CH]246)[CH]357': <networkx.classes.graph.Graph at 0x7f36eb4f54b0>,
#  '[H][C@@]12[BH]34[H][BH]356[H][BH]53[C@]1([H])[BH]4326': <networkx.classes.graph.Graph at 0x7f36eb4f5450>,
#  '[BH]123[BH]45[CH]67[BH]89[CH]1([BH]2486)[BH]3597': <networkx.classes.graph.Graph at 0x7f36eb4f53f0>,
#  '[H]1[BH]2[H][BH]3[BH]24[BH]1[H][BH]4[H]3': <networkx.classes.graph.Graph at 0x7f36eb4f5390>,
#  '[BH]123[CH]45[BH]167[BH]18[CH]9%10[BH]216[BH]394[BH]8%1057': <networkx.classes.graph.Graph at 0x7f36eb4f5330>,
#  '[B@@]123B456B178[B@@]49B714B822B337C211B492C131B75=B621': <networkx.classes.graph.Graph at 0x7f36eb4f52d0>,
#  '[Ba]': <networkx.classes.graph.Graph at 0x7f36eb4f5270>,
#  '[Bi]': <networkx.classes.graph.Graph at 0x7f36eb4f5210>,
#  '[Bi].[Bi]': <networkx.classes.graph.Graph at 0x7f36eb4f51b0>,
#  'C1(=C(C(=C(C(=C1F)F)Br)F)F)F': <networkx.classes.graph.Graph at 0x7f36eb4f5150>,
#  'C1=CC=C(C=C1)Br': <networkx.classes.graph.Graph at 0x7f36eb4f50f0>,
#  '[Ti](Br)(Br)(Br)Br': <networkx.classes.graph.Graph at 0x7f36eb4f5090>,
#  'C(F)(F)(F)Br': <networkx.classes.graph.Graph at 0x7f36eb4f5030>,
#  'C([GeH3])Br': <networkx.classes.graph.Graph at 0x7f36eb4f4fd0>,
#  '[2H]C([2H])Br': <networkx.classes.graph.Graph at 0x7f36eb4f4f70>,
#  'C[SiH2]Br': <networkx.classes.graph.Graph at 0x7f36eb4f4f10>,
#  'C[GeH](C)Br': <networkx.classes.graph.Graph at 0x7f36eb4f4eb0>,
#  'C(CBr)[SiH3]': <networkx.classes.graph.Graph at 0x7f36eb4f4e50>,
#  'C(F)(F)(F)[Ge](C(F)(F)F)(C(F)(F)F)Br': <networkx.classes.graph.Graph at 0x7f36eb4f4df0>,
#  'C[Ge](C)(C)Br': <networkx.classes.graph.Graph at 0x7f36eb4f4d90>,
#  'C[Si](C)(C)Br': <networkx.classes.graph.Graph at 0x7f36eb4f4d30>,
#  'C[Sn](C)(C)Br': <networkx.classes.graph.Graph at 0x7f36eb4f4cd0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Mn]Br': <networkx.classes.graph.Graph at 0x7f36eb4f4c70>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C]#Br.[Co].[Co].[Co]': <networkx.classes.graph.Graph at 0x7f36eb4f4c10>,
#  'FBr(F)(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f4bb0>,
#  '[GeH3]Br': <networkx.classes.graph.Graph at 0x7f36eb4f4b50>,
#  'Br': <networkx.classes.graph.Graph at 0x7f36eb4f4af0>,
#  '[SiH3]Br': <networkx.classes.graph.Graph at 0x7f36eb4f4a90>,
#  'BrI': <networkx.classes.graph.Graph at 0x7f36eb4f4a30>,
#  'BrBr': <networkx.classes.graph.Graph at 0x7f36eb4f49d0>,
#  'C([GeH3])(Br)Br': <networkx.classes.graph.Graph at 0x7f36eb4f4970>,
#  'C([SiH3])(Br)Br': <networkx.classes.graph.Graph at 0x7f36eb4f4640>,
#  'C(F)(F)(F)[Ge](C(F)(F)F)(Br)Br': <networkx.classes.graph.Graph at 0x7f36eb4f45e0>,
#  'C[Ge](C)(Br)Br': <networkx.classes.graph.Graph at 0x7f36eb4f4580>,
#  'C[Si](C)(Br)Br': <networkx.classes.graph.Graph at 0x7f36eb4f4520>,
#  'Br.Br.[Fe].[Fe].[N]=O.[N]=O.[N]=O.[N]=O': <networkx.classes.graph.Graph at 0x7f36eb4f44c0>,
#  'C(F)(F)(F)[Ge](Br)(Br)Br': <networkx.classes.graph.Graph at 0x7f36eb4f4460>,
#  'C([GeH3])(Br)(Br)Br': <networkx.classes.graph.Graph at 0x7f36eb4f4400>,
#  'C([Si])(Br)(Br)Br': <networkx.classes.graph.Graph at 0x7f36eb4f43a0>,
#  'C(Br)(Br)(Br)Br': <networkx.classes.graph.Graph at 0x7f36eb4f4340>,
#  '[Ge](Br)(Br)(Br)Br': <networkx.classes.graph.Graph at 0x7f36eb4f42e0>,
#  '[Si](Br)(Br)(Br)Br': <networkx.classes.graph.Graph at 0x7f36eb4f4280>,
#  'Br[Sn](Br)(Br)Br': <networkx.classes.graph.Graph at 0x7f36eb4f4220>,
#  '[B]N(C)C , C(C)#N.B': <networkx.classes.graph.Graph at 0x7f36eb4f41c0>,
#  'C[N-]C.[B+3].[B+3]': <networkx.classes.graph.Graph at 0x7f36eb4f4160>,
#  'B(=BC)B=BC': <networkx.classes.graph.Graph at 0x7f36eb4f4100>,
#  'CCOC(=O)CBr': <networkx.classes.graph.Graph at 0x7f36eb4f40a0>,
#  'C[Si](Br)(Br)Br': <networkx.classes.graph.Graph at 0x7f36eb4f56c0>,
#  'C(F)(F)(F)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f5720>,
#  'C(OCl)(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f5780>,
#  'CCl': <networkx.classes.graph.Graph at 0x7f36eb4f57e0>,
#  'C[SiH2]Cl': <networkx.classes.graph.Graph at 0x7f36eb4f5840>,
#  'C(F)(F)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f58a0>,
#  'C(Cl)(Cl)[GeH3]': <networkx.classes.graph.Graph at 0x7f36eb4f5900>,
#  'C(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f5960>,
#  'C([SiH3])(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f59c0>,
#  'C(=O)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f5a20>,
#  'C(F)(Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f5a80>,
#  'C(F)(F)(F)[Ge](Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f5ae0>,
#  'C(Cl)(Cl)(Cl)[GeH3]': <networkx.classes.graph.Graph at 0x7f36eb4f5b40>,
#  '[2H]C(Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f5ba0>,
#  'C([SiH3])(Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f5c00>,
#  'C[Sn](Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f5c60>,
#  'C(Cl)(Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f5cc0>,
#  'CP1(=NP(=NP(=N1)(Cl)Cl)(Cl)Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f5d20>,
#  'C(F)[GeH3]': <networkx.classes.graph.Graph at 0x7f36eb4f5d80>,
#  'CF': <networkx.classes.graph.Graph at 0x7f36eb4f5de0>,
#  'C(F)[SiH3]': <networkx.classes.graph.Graph at 0x7f36eb4f5e40>,
#  'C(F)(F)[GeH3]': <networkx.classes.graph.Graph at 0x7f36eb4f5ea0>,
#  'C(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f5f00>,
#  'C(F)(F)[SiH3]': <networkx.classes.graph.Graph at 0x7f36eb4f5f60>,
#  'C(=O)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f5fc0>,
#  'C(F)(F)(F)[GeH3]': <networkx.classes.graph.Graph at 0x7f36eb4f6020>,
#  'C(F)(F)(F)[Ge](I)(I)I': <networkx.classes.graph.Graph at 0x7f36eb4f6080>,
#  'C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f60e0>,
#  'C(F)(F)(F)I': <networkx.classes.graph.Graph at 0x7f36eb4f6140>,
#  'C(N=O)(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f61a0>,
#  'C(F)(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f6200>,
#  'C(F)(F)(F)[Ge](F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f6260>,
#  'C[GeH](I)I': <networkx.classes.graph.Graph at 0x7f36eb4f62c0>,
#  'C([GeH3])I': <networkx.classes.graph.Graph at 0x7f36eb4f6320>,
#  'C[GeH3]': <networkx.classes.graph.Graph at 0x7f36eb4f6380>,
#  'C#N': <networkx.classes.graph.Graph at 0x7f36eb4f63e0>,
#  'C(#N)O': <networkx.classes.graph.Graph at 0x7f36eb4f6440>,
#  'C(#N)N': <networkx.classes.graph.Graph at 0x7f36eb4f64a0>,
#  'C=O': <networkx.classes.graph.Graph at 0x7f36eb4f6500>,
#  'C(=O)O': <networkx.classes.graph.Graph at 0x7f36eb4f6560>,
#  'CI': <networkx.classes.graph.Graph at 0x7f36eb4f65c0>,
#  'C(=O)N': <networkx.classes.graph.Graph at 0x7f36eb4f6620>,
#  'CON=O': <networkx.classes.graph.Graph at 0x7f36eb4f6680>,
#  'C': <networkx.classes.graph.Graph at 0x7f36eb4f66e0>,
#  'C([SiH3])(I)I': <networkx.classes.graph.Graph at 0x7f36eb4f6740>,
#  'C(=O)(N)N': <networkx.classes.graph.Graph at 0x7f36eb4f67a0>,
#  'CO': <networkx.classes.graph.Graph at 0x7f36eb4f6800>,
#  'CS': <networkx.classes.graph.Graph at 0x7f36eb4f6860>,
#  'C([SiH3])I': <networkx.classes.graph.Graph at 0x7f36eb4f68c0>,
#  'CN': <networkx.classes.graph.Graph at 0x7f36eb4f6920>,
#  'C[SiH3]': <networkx.classes.graph.Graph at 0x7f36eb4f6980>,
#  'C(=O)=[Mn].[N-]=O.[N-]=O.[N-]=O': <networkx.classes.graph.Graph at 0x7f36eb4f69e0>,
#  'C(#N)N=O': <networkx.classes.graph.Graph at 0x7f36eb4f6a40>,
#  '[C]#[O]': <networkx.classes.graph.Graph at 0x7f36eb4f6aa0>,
#  'C(=O)=S': <networkx.classes.graph.Graph at 0x7f36eb4f6b00>,
#  'C(=O)=O': <networkx.classes.graph.Graph at 0x7f36eb4f6b60>,
#  'C(=S)=S': <networkx.classes.graph.Graph at 0x7f36eb4f6bc0>,
#  '[CH3-].[CH3-].[Cd+2]': <networkx.classes.graph.Graph at 0x7f36eb4f6c20>,
#  'CC[GeH2]Cl': <networkx.classes.graph.Graph at 0x7f36eb4f6c80>,
#  'C=CCl': <networkx.classes.graph.Graph at 0x7f36eb4f6ce0>,
#  'CCCl': <networkx.classes.graph.Graph at 0x7f36eb4f6d40>,
#  'CC[SiH2]Cl': <networkx.classes.graph.Graph at 0x7f36eb4f6da0>,
#  'C(F)(F)(F)[Ge](C(F)(F)F)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f6e00>,
#  'CC[GeH](Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f6e60>,
#  'C(=C\\Cl)\\Cl': <networkx.classes.graph.Graph at 0x7f36eb4f6ec0>,
#  'C(=C/Cl)\\Cl': <networkx.classes.graph.Graph at 0x7f36eb4f6f20>,
#  'C=C(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f6f80>,
#  'CC(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f6fe0>,
#  'C[Si](C)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f7040>,
#  'C[Sn](C)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f70a0>,
#  'C(=C(Cl)Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f7100>,
#  'CC(Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f7160>,
#  'C(=C(Cl)Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb4f71c0>,
#  'CP1(=NP(=NP(=N1)(Cl)Cl)(Cl)Cl)C': <networkx.classes.graph.Graph at 0x7f36eb4f7220>,
#  'CC[GeH2]F': <networkx.classes.graph.Graph at 0x7f36eb4f7280>,
#  'C=CF': <networkx.classes.graph.Graph at 0x7f36eb4f72e0>,
#  'CCF': <networkx.classes.graph.Graph at 0x7f36eb4f7340>,
#  'C[SiH](C)F': <networkx.classes.graph.Graph at 0x7f36eb4f73a0>,
#  'C=C(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f7400>,
#  'C(=O)OC(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f7460>,
#  'C=CF.F': <networkx.classes.graph.Graph at 0x7f36eb4f74c0>,
#  'C(=C(F)F)F': <networkx.classes.graph.Graph at 0x7f36eb4f7520>,
#  'C(=O)OC(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f7580>,
#  'CC(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f75e0>,
#  'COC(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f7640>,
#  'CC(N(F)F)F': <networkx.classes.graph.Graph at 0x7f36eb4f76a0>,
#  'C(=C(F)F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f7700>,
#  'C(C(F)(F)F)(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f7760>,
#  'C(F)(F)(F)[GeH2]C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f77c0>,
#  'C(F)(F)(F)[Ge](C(F)(F)F)(I)I': <networkx.classes.graph.Graph at 0x7f36eb4f7820>,
#  'C(F)(F)(F)[Hg]C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f7880>,
#  'C(N(C(F)(F)F)[O])(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f78e0>,
#  'C(OOC(F)(F)F)(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f7940>,
#  'C(OOOC(F)(F)F)(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f79a0>,
#  'C(F)(F)(F)[Ge](C(F)(F)F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb4f7a00>,
#  '[C-](=O)N=O.[C-](=O)N=O.[Fe+2]': <networkx.classes.graph.Graph at 0x7f36eb4f7a60>,
#  'C[Ge](C)(I)I': <networkx.classes.graph.Graph at 0x7f36eb4f7ac0>,
#  'C[GeH](C)I': <networkx.classes.graph.Graph at 0x7f36eb4f7b20>,
#  'C[GeH2]C': <networkx.classes.graph.Graph at 0x7f36eb4f7b80>,
#  'C[GeH2]O[GeH2]C': <networkx.classes.graph.Graph at 0x7f36eb4f7be0>,
#  'C[GeH2]S[GeH2]C': <networkx.classes.graph.Graph at 0x7f36eb4f7c40>,
#  'C#C': <networkx.classes.graph.Graph at 0x7f36eb4f7ca0>,
#  'C=C=O': <networkx.classes.graph.Graph at 0x7f36eb4f7d00>,
#  'C=CI': <networkx.classes.graph.Graph at 0x7f36eb4f7d60>,
#  'CC#N': <networkx.classes.graph.Graph at 0x7f36eb4f7dc0>,
#  'CSC#N': <networkx.classes.graph.Graph at 0x7f36eb4f7e20>,
#  'C=C': <networkx.classes.graph.Graph at 0x7f36eb4f7e80>,
#  'C(#N)N=C(N)N': <networkx.classes.graph.Graph at 0x7f36eb4f7ee0>,
#  'CC=O': <networkx.classes.graph.Graph at 0x7f36eb4f7f40>,
#  'COC=O': <networkx.classes.graph.Graph at 0x7f36eb4f7fa0>,
#  'C[Hg]C': <networkx.classes.graph.Graph at 0x7f36eb3d8040>,
#  'C[Si](C)(I)I': <networkx.classes.graph.Graph at 0x7f36eb3d80a0>,
#  'CCO': <networkx.classes.graph.Graph at 0x7f36eb3d8100>,
#  'COC': <networkx.classes.graph.Graph at 0x7f36eb3d8160>,
#  'CS(=O)C': <networkx.classes.graph.Graph at 0x7f36eb3d81c0>,
#  'CS(=O)(=O)C': <networkx.classes.graph.Graph at 0x7f36eb3d8220>,
#  'COS(=O)(=O)C': <networkx.classes.graph.Graph at 0x7f36eb3d8280>,
#  'COS(=O)(=O)OC': <networkx.classes.graph.Graph at 0x7f36eb3d82e0>,
#  'CSC': <networkx.classes.graph.Graph at 0x7f36eb3d8340>,
#  'C[Se]C': <networkx.classes.graph.Graph at 0x7f36eb3d83a0>,
#  'C[Te]C': <networkx.classes.graph.Graph at 0x7f36eb3d8400>,
#  '[CH3-].[CH3-].[Zn+2]': <networkx.classes.graph.Graph at 0x7f36eb3d8460>,
#  'C[SiH2]CI': <networkx.classes.graph.Graph at 0x7f36eb3d84c0>,
#  'CC[SiH3]': <networkx.classes.graph.Graph at 0x7f36eb3d8520>,
#  'C[SiH2]O[SiH2]C': <networkx.classes.graph.Graph at 0x7f36eb3d8580>,
#  'C[SiH2]S[SiH2]C': <networkx.classes.graph.Graph at 0x7f36eb3d85e0>,
#  'C[SiH2][Se][SiH2]C': <networkx.classes.graph.Graph at 0x7f36eb3d8640>,
#  'C[SiH2][Te][SiH2]C': <networkx.classes.graph.Graph at 0x7f36eb3d86a0>,
#  'C(#N)C#N': <networkx.classes.graph.Graph at 0x7f36eb3d8700>,
#  'C(F)(F)(F)[Ge](C(F)(F)F)(C(F)(F)F)Cl': <networkx.classes.graph.Graph at 0x7f36eb3d8760>,
#  'C[Ge](C)(C)Cl': <networkx.classes.graph.Graph at 0x7f36eb3d87c0>,
#  'C[Si](C)(C)Cl': <networkx.classes.graph.Graph at 0x7f36eb3d8820>,
#  'C[Sn](C)(C)Cl': <networkx.classes.graph.Graph at 0x7f36eb3d8880>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[N-]=O.[Co]': <networkx.classes.graph.Graph at 0x7f36eb3d88e0>,
#  '[2H]C([2H])([2H])C(=O)C([2H])([2H])[2H]': <networkx.classes.graph.Graph at 0x7f36eb3d8940>,
#  'C[Ge](C)(C)F': <networkx.classes.graph.Graph at 0x7f36eb3d89a0>,
#  'C[Si](C)(C)F': <networkx.classes.graph.Graph at 0x7f36eb3d8a00>,
#  'C(#CF)C(F)F': <networkx.classes.graph.Graph at 0x7f36eb3d8a60>,
#  'CC(=C(F)F)F': <networkx.classes.graph.Graph at 0x7f36eb3d8ac0>,
#  'C(C(=O)O)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3d8b20>,
#  'C1(C(C1(F)F)(F)F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3d8b80>,
#  'C(=O)(C(F)(F)F)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3d8be0>,
#  'C(C(F)(F)F)(C(F)(F)F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3d8c40>,
#  'C(C(F)(F)SC(F)(F)F)(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3d8ca0>,
#  'C(F)(F)(F)[GeH](C(F)(F)F)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3d8d00>,
#  'C(F)(F)(F)[Ge](C(F)(F)F)(C(F)(F)F)I': <networkx.classes.graph.Graph at 0x7f36eb3d8d60>,
#  'FP(F)F.FP(F)F.FP(F)F.[C-]#[O+].[C-]#[O+].[C-]#[O+].[Mo]': <networkx.classes.graph.Graph at 0x7f36eb3d8dc0>,
#  'C(F)(F)(F)P(C(F)(F)F)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3d8e20>,
#  'C(F)(F)(F)[Ge](C(F)(F)F)(C(F)(F)F)F': <networkx.classes.graph.Graph at 0x7f36eb3d8e80>,
#  'C[Ge](C)(C)I': <networkx.classes.graph.Graph at 0x7f36eb3d8ee0>,
#  'C[Ge](C)(C)N=[N+]=[N-]': <networkx.classes.graph.Graph at 0x7f36eb3d8f40>,
#  'C[GeH](C)C': <networkx.classes.graph.Graph at 0x7f36eb3d8fa0>,
#  'C1=NOS2=C1C=NO2': <networkx.classes.graph.Graph at 0x7f36eb3d9000>,
#  'C1=NO[Se]2=C1C=NO2': <networkx.classes.graph.Graph at 0x7f36eb3d9060>,
#  'N#C[Te]OC(=N)O': <networkx.classes.graph.Graph at 0x7f36eb3d90c0>,
#  'C=CC#N': <networkx.classes.graph.Graph at 0x7f36eb3d9120>,
#  'CC#C': <networkx.classes.graph.Graph at 0x7f36eb3d9180>,
#  'C=CC=O': <networkx.classes.graph.Graph at 0x7f36eb3d91e0>,
#  'COC#C': <networkx.classes.graph.Graph at 0x7f36eb3d9240>,
#  'CC=C': <networkx.classes.graph.Graph at 0x7f36eb3d92a0>,
#  'CC(=O)C': <networkx.classes.graph.Graph at 0x7f36eb3d9300>,
#  'CCC=O': <networkx.classes.graph.Graph at 0x7f36eb3d9360>,
#  'CC(=O)OC': <networkx.classes.graph.Graph at 0x7f36eb3d93c0>,
#  'CCC(=O)O': <networkx.classes.graph.Graph at 0x7f36eb3d9420>,
#  'CC(=O)OOC': <networkx.classes.graph.Graph at 0x7f36eb3d9480>,
#  'C1OP2OCP1CO2': <networkx.classes.graph.Graph at 0x7f36eb3d94e0>,
#  'CN(C)C=O': <networkx.classes.graph.Graph at 0x7f36eb3d9540>,
#  'CC(C)[N+](=O)[O-]': <networkx.classes.graph.Graph at 0x7f36eb3d95a0>,
#  'CCC': <networkx.classes.graph.Graph at 0x7f36eb3d9600>,
#  'C[Si](C)(C)I': <networkx.classes.graph.Graph at 0x7f36eb3d9660>,
#  'C[Sn](C)(C)I': <networkx.classes.graph.Graph at 0x7f36eb3d96c0>,
#  'CP(C)C.[Mn+3].[N-]=O.[N-]=O.[N-]=O': <networkx.classes.graph.Graph at 0x7f36eb3d9720>,
#  'CN(C)C': <networkx.classes.graph.Graph at 0x7f36eb3d9780>,
#  'CP(=O)(C)C': <networkx.classes.graph.Graph at 0x7f36eb3d97e0>,
#  'COP(OC)OC': <networkx.classes.graph.Graph at 0x7f36eb3d9840>,
#  'COP(=O)(OC)OC': <networkx.classes.graph.Graph at 0x7f36eb3d98a0>,
#  'CP(C)C': <networkx.classes.graph.Graph at 0x7f36eb3d9900>,
#  'CP(C)SC': <networkx.classes.graph.Graph at 0x7f36eb3d9960>,
#  'CP(C)CN': <networkx.classes.graph.Graph at 0x7f36eb3d99c0>,
#  'C[SiH](C)C': <networkx.classes.graph.Graph at 0x7f36eb3d9a20>,
#  'C(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb3d9a80>,
#  'CCOC(=O)CCl': <networkx.classes.graph.Graph at 0x7f36eb3d9ae0>,
#  'CCCCCl': <networkx.classes.graph.Graph at 0x7f36eb3d9b40>,
#  'C[Si](C)(C)CCl': <networkx.classes.graph.Graph at 0x7f36eb3d9ba0>,
#  '[H-].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Co]': <networkx.classes.graph.Graph at 0x7f36eb3d9c00>,
#  'CCOC(=O)CF': <networkx.classes.graph.Graph at 0x7f36eb3d9c60>,
#  'CCOC(=O)C(F)F': <networkx.classes.graph.Graph at 0x7f36eb3d9cc0>,
#  'C[GeH](C)OC(=O)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3d9d20>,
#  'C[Ge](C)(C)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3d9d80>,
#  'C(=C(F)F)(C(=C(F)F)F)F': <networkx.classes.graph.Graph at 0x7f36eb3d9de0>,
#  'C(#CC(F)(F)F)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3d9e40>,
#  'C[Ge](C)(C(F)(F)F)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3d9ea0>,
#  'C(=C(/C(F)(F)F)\\F)(\\C(F)(F)F)/F': <networkx.classes.graph.Graph at 0x7f36eb3d9f00>,
#  'C1(C(C(C1(F)F)(F)F)(F)F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3d9f60>,
#  'C[Ge](C(F)(F)F)(C(F)(F)F)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3d9fc0>,
#  'C(C(F)(F)F)(C(F)(F)F)(C(F)(F)F)O': <networkx.classes.graph.Graph at 0x7f36eb3da020>,
#  'C(F)(F)(F)[Ge](C(F)(F)F)(C(F)(F)F)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3da080>,
#  'C(=C/C(=O)[O-])\\C(=O)[O-].[Fe+2]': <networkx.classes.graph.Graph at 0x7f36eb3da0e0>,
#  'C[Ge](C)(C)C#N': <networkx.classes.graph.Graph at 0x7f36eb3da140>,
#  'C[Ge](C)(C)N=C=S': <networkx.classes.graph.Graph at 0x7f36eb3da1a0>,
#  'C[Ge](C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb3da200>,
#  'CC[GeH2]O[GeH2]CC': <networkx.classes.graph.Graph at 0x7f36eb3da260>,
#  'C[GeH](C)S[GeH](C)C': <networkx.classes.graph.Graph at 0x7f36eb3da2c0>,
#  'C[GeH](C)[Se][GeH](C)C': <networkx.classes.graph.Graph at 0x7f36eb3da320>,
#  'C[GeH](C)[Te][GeH](C)C': <networkx.classes.graph.Graph at 0x7f36eb3da380>,
#  'O=C[O-].O=C[O-].O=C[O-].O=C[O-].[Mo+2].[Mo+2]': <networkx.classes.graph.Graph at 0x7f36eb3da3e0>,
#  'C1=COC=C1': <networkx.classes.graph.Graph at 0x7f36eb3da440>,
#  'C1=CSC=C1': <networkx.classes.graph.Graph at 0x7f36eb3da4a0>,
#  'CC#CC': <networkx.classes.graph.Graph at 0x7f36eb3da500>,
#  'CC(=O)OC=C': <networkx.classes.graph.Graph at 0x7f36eb3da560>,
#  'CC(=O)OC(=O)C': <networkx.classes.graph.Graph at 0x7f36eb3da5c0>,
#  'CP1(=O)CCC(=O)O1': <networkx.classes.graph.Graph at 0x7f36eb3da620>,
#  'CCOC(=O)C': <networkx.classes.graph.Graph at 0x7f36eb3da680>,
#  'CC(C)(C)ON=O': <networkx.classes.graph.Graph at 0x7f36eb3da6e0>,
#  'CCCC': <networkx.classes.graph.Graph at 0x7f36eb3da740>,
#  'CC(C)N(C)N=O': <networkx.classes.graph.Graph at 0x7f36eb3da7a0>,
#  'CP(=C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb3da800>,
#  'C[Si](C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb3da860>,
#  'C[Sn](C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb3da8c0>,
#  'C[SiH](C)O[SiH](C)C': <networkx.classes.graph.Graph at 0x7f36eb3da920>,
#  'C[SiH](C)S[SiH](C)C': <networkx.classes.graph.Graph at 0x7f36eb3da980>,
#  'C[SiH](C)[Se][SiH](C)C': <networkx.classes.graph.Graph at 0x7f36eb3da9e0>,
#  'C[SiH](C)[Te][SiH](C)C': <networkx.classes.graph.Graph at 0x7f36eb3daa40>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[N-]=O.[Mn]': <networkx.classes.graph.Graph at 0x7f36eb3daaa0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Ni]': <networkx.classes.graph.Graph at 0x7f36eb3dab00>,
#  'C1=C[CH]C=C1.N#[O+].N#[O+].[Cl-].[Cr]': <networkx.classes.graph.Graph at 0x7f36eb3dab60>,
#  'N#[O+].N#[O+].[CH]1C=CC=C1.[Cl-].[Mo]': <networkx.classes.graph.Graph at 0x7f36eb3dabc0>,
#  'N#[O+].N#[O+].[CH]1C=CC=C1.[Cl-].[W]': <networkx.classes.graph.Graph at 0x7f36eb3dac20>,
#  'CC(C)(C)C(=O)Cl': <networkx.classes.graph.Graph at 0x7f36eb3dac80>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].Cl[Mn]': <networkx.classes.graph.Graph at 0x7f36eb3dace0>,
#  'C[Ge](C)(C)OC(=O)C(Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb3dad40>,
#  'C[Si](C)(C)OC(=O)C(Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb3dada0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Si](Cl)(Cl)Cl.[Mn]': <networkx.classes.graph.Graph at 0x7f36eb3dae00>,
#  'ClP(Cl)Cl.C(=O)=[Mo](=C=O)(=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb3dae60>,
#  'FP(F)F.C(=O)=[Cr](=C=O)(=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb3daec0>,
#  '[CH-]1C=CC=C1.[N-]=O.[N-]=O.N(=O)[O-].[Cr+4]': <networkx.classes.graph.Graph at 0x7f36eb3daf20>,
#  'C[Si](C)(C)OC(=O)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3daf80>,
#  'C(=O)=[Mn]([Si](F)(F)F)(=C=O)(=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb3dafe0>,
#  'FP(F)F.C(=O)=[Mo](=C=O)(=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb3db040>,
#  'C(C(=O)C(F)(F)F)C(=O)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb3db0a0>,
#  '[CH2][CH][CH2].[C-]#[O+].[C-]#[O+].[N-]=O.[Fe+2]': <networkx.classes.graph.Graph at 0x7f36eb3db100>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Fe]': <networkx.classes.graph.Graph at 0x7f36eb3db160>,
#  'CC(=O)O[Ge](C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb3db1c0>,
#  '[H-].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Mn]': <networkx.classes.graph.Graph at 0x7f36eb3db220>,
#  '[CH-]1C=CC=C1.[N-]=O.[Ni+2]': <networkx.classes.graph.Graph at 0x7f36eb3db280>,
#  'C(=C=[C+]N)C#CN': <networkx.classes.graph.Graph at 0x7f36eb3db2e0>,
#  'C1(C=CC=C1)[WH](N=O)N=O': <networkx.classes.graph.Graph at 0x7f36eb3db340>,
#  'CC=C(C)C(=O)O': <networkx.classes.graph.Graph at 0x7f36eb3db3a0>,
#  'CC(C)(C)C#N': <networkx.classes.graph.Graph at 0x7f36eb3db400>,
#  'CC12COP(OC1)OC2': <networkx.classes.graph.Graph at 0x7f36eb3db460>,
#  'CCC(=O)OCC': <networkx.classes.graph.Graph at 0x7f36eb3db4c0>,
#  'CC(C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb3db520>,
#  'CCCCC': <networkx.classes.graph.Graph at 0x7f36eb3db580>,
#  'CC(=O)O[Si](C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb3db5e0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Mn]I': <networkx.classes.graph.Graph at 0x7f36eb3db640>,
#  'C1(=C(C(=C(C(=C1F)F)Cl)F)F)F': <networkx.classes.graph.Graph at 0x7f36eb3db6a0>,
#  '[CH2-][C-](Cl)Cl.[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Fe+2]': <networkx.classes.graph.Graph at 0x7f36eb3db700>,
#  'C(=O)=[Cr](=C=S)(=C=O)(=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb3db760>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Cr]': <networkx.classes.graph.Graph at 0x7f36eb3db7c0>,
#  'C1=CC(=CC=C1[N+](=O)[O-])F': <networkx.classes.graph.Graph at 0x7f36eb3db820>,
#  'C1=CC=C(C=C1)F': <networkx.classes.graph.Graph at 0x7f36eb3db880>,
#  'C1=CC(=CC(=C1)F)N': <networkx.classes.graph.Graph at 0x7f36eb3db8e0>,
#  'C1=CC=C(C(=C1)N)F': <networkx.classes.graph.Graph at 0x7f36eb3db940>,
#  'C1=CC(=CC=C1N)F': <networkx.classes.graph.Graph at 0x7f36eb3db9a0>,
#  'C1=CC=C(C(=C1)O)F': <networkx.classes.graph.Graph at 0x7f36eb3dba00>,
#  'C1=CC(=CC=C1F)F': <networkx.classes.graph.Graph at 0x7f36eb3dba60>,
#  'C1=C(C=C(C=C1F)F)F': <networkx.classes.graph.Graph at 0x7f36eb3dbac0>,
#  'C1=C(C(=CC(=C1F)F)F)F': <networkx.classes.graph.Graph at 0x7f36eb3dbb20>,
#  'C1=C(C(=C(C(=C1F)F)F)F)F': <networkx.classes.graph.Graph at 0x7f36eb3dbb80>,
#  'C1(=C(C(=C(C(=C1F)F)I)F)F)F': <networkx.classes.graph.Graph at 0x7f36eb3dbbe0>,
#  'C1(=C(C(=C(C(=C1F)F)F)F)F)F': <networkx.classes.graph.Graph at 0x7f36eb3dbc40>,
#  'C[N+]#[C-].C(=O)=[Fe](=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb3dbca0>,
#  'C=C.C(=O)=[Fe](=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb3dbd00>,
#  'CP(C)C.CP(C)C.N(=O)[Fe]N=O': <networkx.classes.graph.Graph at 0x7f36eb3dbd60>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[S-2].[S-2].[Fe+2].[Fe+2]': <networkx.classes.graph.Graph at 0x7f36eb3dbdc0>,
#  'C[Ge](C)(C)O[Ge](C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb3dbe20>,
#  'C[Ge](C)(C)S[Ge](C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb3dbe80>,
#  'C[Ge](C)C.C[Ge](C)C.[Se]': <networkx.classes.graph.Graph at 0x7f36eb3dbee0>,
#  'C[Ge](C)C.C[Ge](C)C.[Te]': <networkx.classes.graph.Graph at 0x7f36eb3dbf40>,
#  '[CH3-].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Mn]': <networkx.classes.graph.Graph at 0x7f36eb3dbfa0>,
#  '[CH3-].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Re]': <networkx.classes.graph.Graph at 0x7f36eb2dc040>,
#  'C1=CC=C(C=C1)I': <networkx.classes.graph.Graph at 0x7f36eb2dc0a0>,
#  'C1=CC(=CN=C1)C(=O)O': <networkx.classes.graph.Graph at 0x7f36eb2dc100>,
#  'C1=CN=CC=C1C(=O)O': <networkx.classes.graph.Graph at 0x7f36eb2dc160>,
#  'C1=CC=NC(=C1)C(=O)O': <networkx.classes.graph.Graph at 0x7f36eb2dc1c0>,
#  'C1=CC=CC=C1': <networkx.classes.graph.Graph at 0x7f36eb2dc220>,
#  'C1=CC(=CC=C1N)[N+](=O)[O-]': <networkx.classes.graph.Graph at 0x7f36eb2dc280>,
#  'C1=CC=C(C=C1)O': <networkx.classes.graph.Graph at 0x7f36eb2dc2e0>,
#  'C1=CC=C(C=C1)N': <networkx.classes.graph.Graph at 0x7f36eb2dc340>,
#  'C1C2CC3CC1OP(O2)O3': <networkx.classes.graph.Graph at 0x7f36eb2dc3a0>,
#  'C1CCCCC1': <networkx.classes.graph.Graph at 0x7f36eb2dc400>,
#  'CCCCCC': <networkx.classes.graph.Graph at 0x7f36eb2dc460>,
#  'CN(C)P(N(C)C)N(C)C': <networkx.classes.graph.Graph at 0x7f36eb2dc4c0>,
#  'CN1P2N(P3N(P1N(P(N2C)N3C)C)C)C': <networkx.classes.graph.Graph at 0x7f36eb2dc520>,
#  'C[Si](C)(C)O[Si](C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb2dc580>,
#  'C[Si](C)(C)S[Si](C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb2dc5e0>,
#  'C[Si](C)(C)[Se][Si](C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb2dc640>,
#  'C[Si](C)(C)[Te][Si](C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb2dc6a0>,
#  'C[Sn](C)C.C[Sn](C)C': <networkx.classes.graph.Graph at 0x7f36eb2dc700>,
#  'C[Si](C)(C)N[Si](C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb2dc760>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Mo]': <networkx.classes.graph.Graph at 0x7f36eb2dc7c0>,
#  'C(#N)C(=C(C#N)C#N)C#N': <networkx.classes.graph.Graph at 0x7f36eb2dc820>,
#  'C(#N)C1(C(O1)(C#N)C#N)C#N': <networkx.classes.graph.Graph at 0x7f36eb2dc880>,
#  'C(=O)=[W](=C=S)(=C=O)(=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb2dc8e0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[V]': <networkx.classes.graph.Graph at 0x7f36eb2dc940>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[W]': <networkx.classes.graph.Graph at 0x7f36eb2dc9a0>,
#  'C1=CC=C(C(=C1)C=O)Cl': <networkx.classes.graph.Graph at 0x7f36eb2dca00>,
#  '[C-]#[O+].[C-]#[O+].C1=C[CH]C=C1.[Co]': <networkx.classes.graph.Graph at 0x7f36eb2dca60>,
#  'C1(C=CC=C1)[Cr](N=S)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb2dcac0>,
#  '[C-]#[O+].[C-]#[O+].C1=C[CH]C=C1.N#[O+].[Cr]': <networkx.classes.graph.Graph at 0x7f36eb2dcb20>,
#  'C1=CC(=CC=C1C#N)F': <networkx.classes.graph.Graph at 0x7f36eb2dcb80>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-](=O)C(F)(F)F.[Mn]': <networkx.classes.graph.Graph at 0x7f36eb2dcbe0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].C(=C/C=O)\\C=O.[Fe]': <networkx.classes.graph.Graph at 0x7f36eb2dcc40>,
#  '[CH2-]/C=C\\[CH2-].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Fe+2]': <networkx.classes.graph.Graph at 0x7f36eb2dcca0>,
#  '[CH2][C]([CH2])[CH2].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Fe]': <networkx.classes.graph.Graph at 0x7f36eb2dcd00>,
#  'CP(C)C.C(=O)=[Fe](=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb2dcd60>,
#  'C[C-]=O.[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Mn]': <networkx.classes.graph.Graph at 0x7f36eb2dcdc0>,
#  'C=C[CH2].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Mn]': <networkx.classes.graph.Graph at 0x7f36eb2dce20>,
#  '[CH-]1C=CC=C1.C(=O)=[Mo+2]=C=O.[N-]=O': <networkx.classes.graph.Graph at 0x7f36eb2dce80>,
#  'C1=CC=C(C=C1)C#N': <networkx.classes.graph.Graph at 0x7f36eb2dcee0>,
#  'C#CC1=CC=CC=N1': <networkx.classes.graph.Graph at 0x7f36eb2dcf40>,
#  '[2H]C1=C(C(=C(C(=C1[2H])[2H])C#N)[2H])[2H]': <networkx.classes.graph.Graph at 0x7f36eb2dcfa0>,
#  'C1=CC(=CC=C1C=O)[N+](=O)[O-]': <networkx.classes.graph.Graph at 0x7f36eb2dd000>,
#  '[CH-]1C=CC=C1.C(=O)=[W]=C=O.[N-]=O': <networkx.classes.graph.Graph at 0x7f36eb2dd060>,
#  'C1=CC(=CC(=C1)N)C#N': <networkx.classes.graph.Graph at 0x7f36eb2dd0c0>,
#  'C1=CC=C(C(=C1)C#N)N': <networkx.classes.graph.Graph at 0x7f36eb2dd120>,
#  'C1=CC=C(C=C1)C=O': <networkx.classes.graph.Graph at 0x7f36eb2dd180>,
#  'CC1=CC=CC=C1': <networkx.classes.graph.Graph at 0x7f36eb2dd1e0>,
#  'CC1(C(OP(O1)OC)(C)C)C': <networkx.classes.graph.Graph at 0x7f36eb2dd240>,
#  'C#C.[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Co].[Co]': <networkx.classes.graph.Graph at 0x7f36eb2dd2a0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Co].[Co].[Hg]': <networkx.classes.graph.Graph at 0x7f36eb2dd300>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Co].[Co]': <networkx.classes.graph.Graph at 0x7f36eb2dd360>,
#  'CC(=[Cr])OC.[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+]': <networkx.classes.graph.Graph at 0x7f36eb2dd3c0>,
#  'CC(=O)[O-].CC(=O)[O-].CC(=O)[O-].CC(=O)[O-].[Cr+2].[Cr+2]': <networkx.classes.graph.Graph at 0x7f36eb2dd420>,
#  'C1=CC(=CC=C1C#N)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb2dd480>,
#  'C1=CC(=CC=C1C(F)(F)F)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb2dd4e0>,
#  'COC(=O)C=C.[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Fe]': <networkx.classes.graph.Graph at 0x7f36eb2dd540>,
#  'C[Si](C)(C)[N+]#[C-].C(=O)=[Fe](=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb2dd5a0>,
#  'C[S-].C[S-].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Fe].[Fe]': <networkx.classes.graph.Graph at 0x7f36eb2dd600>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[S+].[CH-]1C=CC=C1.[Mn]': <networkx.classes.graph.Graph at 0x7f36eb2dd660>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[CH-]1C=CC=C1.[Mn]': <networkx.classes.graph.Graph at 0x7f36eb2dd6c0>,
#  '[CH2-]C=C.[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Mn]': <networkx.classes.graph.Graph at 0x7f36eb2dd720>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].C1=C[CH]C=C1.[Re]': <networkx.classes.graph.Graph at 0x7f36eb2dd780>,
#  'C(=O)=[Mn](CCC)(=C=O)(=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb2dd7e0>,
#  'CC(=O)C1=CC=CC=C1': <networkx.classes.graph.Graph at 0x7f36eb2dd840>,
#  'CP(C)C.C(=O)=[Mo](=C=O)(=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb2dd8a0>,
#  'P(OC)(OC)OC.C(=O)=[Mo](=C=O)(=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb2dd900>,
#  'CC(=O)[O-].CC(=O)[O-].CC(=O)[O-].CC(=O)[O-].[Mo+2].[Mo+2]': <networkx.classes.graph.Graph at 0x7f36eb2dd960>,
#  'CN(C)C1=CC=C(C=C1)N': <networkx.classes.graph.Graph at 0x7f36eb2dd9c0>,
#  'CC1(CC(OP(O1)OC)(C)C)C': <networkx.classes.graph.Graph at 0x7f36eb2dda20>,
#  'CCCCCCCC': <networkx.classes.graph.Graph at 0x7f36eb2dda80>,
#  'CC(C)(C)N(C(C)(C)C)[O]': <networkx.classes.graph.Graph at 0x7f36eb2ddae0>,
#  'CC12CN(P(N(C1)C)N(C2)C)C': <networkx.classes.graph.Graph at 0x7f36eb2ddb40>,
#  'CP1(=NP(=NP(=NP(=N1)(C)C)(C)C)(C)C)C': <networkx.classes.graph.Graph at 0x7f36eb2ddba0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].C1=CC=C(C=C1)Cl.[Cr]': <networkx.classes.graph.Graph at 0x7f36eb2ddc00>,
#  'C(=S)=[Cr](=C=O)(=C=O)C1=CC=CC=C1': <networkx.classes.graph.Graph at 0x7f36eb2ddc60>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].C1=CC=CC=C1.[Cr]': <networkx.classes.graph.Graph at 0x7f36eb2ddcc0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].C1=CC=NC=C1.[Fe]': <networkx.classes.graph.Graph at 0x7f36eb2ddd20>,
#  'C(C)(C)(C)[N+]#[C-].C(=O)=[Fe](=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb2ddd80>,
#  'C=[Fe](=C=O)(=C=O)(=C=O)=C=O.C(=O)=[Fe](=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb2ddde0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].C1=C[CH]C=C1.[V]': <networkx.classes.graph.Graph at 0x7f36eb2dde40>,
#  'CC1=CC=C[CH]1.[C-]#[O+].[C-]#[O+].[C-]#[O+].[Mn]': <networkx.classes.graph.Graph at 0x7f36eb2ddea0>,
#  '[CH3-].[C-]#[O+].[C-]#[O+].[C-]#[O+].[CH-]1C=CC=C1.[Mo]': <networkx.classes.graph.Graph at 0x7f36eb2ddf00>,
#  'C1=CC=C(C=C1)/C=C/C=O': <networkx.classes.graph.Graph at 0x7f36eb2ddf60>,
#  'CC(C)OP(OC(C)C)OC(C)C': <networkx.classes.graph.Graph at 0x7f36eb2ddfc0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C]#Cl.[Co].[Co].[Co]': <networkx.classes.graph.Graph at 0x7f36eb2de020>,
#  '[CH]1[CH][CH][CH][CH]1.[CH]1[CH][CH][CH][CH]1.[Co]': <networkx.classes.graph.Graph at 0x7f36eb2de080>,
#  'C/C(=C/C(=O)C)/[O-].C/C(=C/C(=O)C)/[O-].[Co+2]': <networkx.classes.graph.Graph at 0x7f36eb2de0e0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[CH].[Co].[Co].[Co]': <networkx.classes.graph.Graph at 0x7f36eb2de140>,
#  'CC1=CC=CC=C1.[C-]#[O+].[C-]#[O+].[C-]#[O+].[Cr]': <networkx.classes.graph.Graph at 0x7f36eb2de1a0>,
#  '[CH]1[CH][CH][CH][CH]1.[CH]1[CH][CH][CH][CH]1.[Cr]': <networkx.classes.graph.Graph at 0x7f36eb2de200>,
#  'C/C(=C\\C(=O)C)/[O-].C/C(=C\\C(=O)C)/[O-].[Cu+2]': <networkx.classes.graph.Graph at 0x7f36eb2de260>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].C1C=CC=CC=C1.[Fe]': <networkx.classes.graph.Graph at 0x7f36eb2de2c0>,
#  'COC(=O)[CH-][CH-]C(=O)OC.[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Fe+2]': <networkx.classes.graph.Graph at 0x7f36eb2de320>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].C1=CC=C[CH+]C=C1.[V]': <networkx.classes.graph.Graph at 0x7f36eb2de380>,
#  'C1=C[CH]C=C1.C1=C[CH]C=C1.[Mg]': <networkx.classes.graph.Graph at 0x7f36eb2de3e0>,
#  'C1=C[CH]C=C1.C1=C[CH]C=C1.[Mn]': <networkx.classes.graph.Graph at 0x7f36eb2de440>,
#  '[CH]1[CH][CH][CH][CH]1.[CH]1[CH][CH][CH][CH]1.[Ni]': <networkx.classes.graph.Graph at 0x7f36eb2de4a0>,
#  'CC1=CC(=C(C=C1)C(=O)C)C': <networkx.classes.graph.Graph at 0x7f36eb2de500>,
#  'C/C(=C\\C(=O)C)/[O-].C/C(=C\\C(=O)C)/[O-].[Ni+2]': <networkx.classes.graph.Graph at 0x7f36eb2de560>,
#  'CCCCCCCCCC': <networkx.classes.graph.Graph at 0x7f36eb2de5c0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Mn].[Mn]': <networkx.classes.graph.Graph at 0x7f36eb2de620>,
#  'CC.[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Co].[Co].[Co]': <networkx.classes.graph.Graph at 0x7f36eb2de680>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]=[O+]C.[Co].[Co].[Co]': <networkx.classes.graph.Graph at 0x7f36eb2de6e0>,
#  'C1(=CC=CC=C1)[N+]#[C-].C(=O)=[Fe](=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb2de740>,
#  'CC1=CC(=C(C=C1C)C(=O)C)C': <networkx.classes.graph.Graph at 0x7f36eb2de7a0>,
#  'C(C)OP(OCC)OCC.C(=O)=[Mo](=C=O)(=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb2de800>,
#  'CN(C)P(N(C)C)N(C)C.C(=O)=[Mo](=C=O)(=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb2de860>,
#  '[CH2]O.[CH2]O.[CH2]O.[CH2]O.[CH2]O.[CH2]O.[CH2]O.[CH2]O.[CH2]O.[CH]O.[CH]O.[CH]O.[Co].[Co].[Co].[Fe].[H]': <networkx.classes.graph.Graph at 0x7f36eb2de8c0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C]#N(C)C.[Co].[Co].[Co]': <networkx.classes.graph.Graph at 0x7f36eb2de920>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Co].[Co].[Co].[Co]': <networkx.classes.graph.Graph at 0x7f36eb2de980>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Fe].[Fe].[Fe]': <networkx.classes.graph.Graph at 0x7f36eb2de9e0>,
#  'C1C=CC=[C-]1.C1C=CC=CC=[C-]1.[V+2]': <networkx.classes.graph.Graph at 0x7f36eb2dea40>,
#  'C=CC[Si](CC=C)(CC=C)CC=C': <networkx.classes.graph.Graph at 0x7f36eb2deaa0>,
#  'C[Si](C)(C)N([Si](C)(C)C)[Sn]N([Si](C)(C)C)[Si](C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb2deb00>,
#  '[C-]#[O+].[C-]#[O+].[CH2].[CH]1C=CC=C1.[CH]1C=CC=C1.[Co].[Co]': <networkx.classes.graph.Graph at 0x7f36eb2deb60>,
#  'C1=CC=C2C(=C1)C3=CC=CC=C3C2=O': <networkx.classes.graph.Graph at 0x7f36eb2debc0>,
#  'C1=CC=C(C=C1)C(=O)C2=CC=CC=C2': <networkx.classes.graph.Graph at 0x7f36eb2dec20>,
#  'C1=CC=C(C=C1)OC(=O)OC2=CC=CC=C2': <networkx.classes.graph.Graph at 0x7f36eb2dec80>,
#  '[C-]#[O+].[C-]#[O+].[CH2].[CH]1C=CC=C1.[CH]1C=CC=C1.[Rh].[Rh]': <networkx.classes.graph.Graph at 0x7f36eb2dece0>,
#  'CC1=C([C](C(=C1C)C)C)C.[C-]#[O+].[C-]#[O+].[C-]#[O+].[Mn]': <networkx.classes.graph.Graph at 0x7f36eb2ded40>,
#  'CC1=C([C](C(=C1C)C)C)C.[C-]#[O+].[C-]#[O+].[C-]#[O+].[Re]': <networkx.classes.graph.Graph at 0x7f36eb2deda0>,
#  'CCCCCCCCCCCCC': <networkx.classes.graph.Graph at 0x7f36eb2dee00>,
#  'CCCC[Sn](CCCC)(CCCC)OC': <networkx.classes.graph.Graph at 0x7f36eb2dee60>,
#  'C[Si](C)(C)C#C[Si](C)(C)C.[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Co].[Co]': <networkx.classes.graph.Graph at 0x7f36eb2deec0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[CH]1[CH][CH][CH][CH]1.[CH]1[CH][CH][CH][CH]1.[Fe].[Fe]': <networkx.classes.graph.Graph at 0x7f36eb2def20>,
#  'C1C2=CC=CC=C2C(=O)C3=CC=CC=C31': <networkx.classes.graph.Graph at 0x7f36eb2def80>,
#  'CC(C)(C)C#C[Si](C)(C)C.[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Co].[Co]': <networkx.classes.graph.Graph at 0x7f36eb2defe0>,
#  'C(=C(\\[O-])/C(F)(F)F)\\C(=O)C(F)(F)F.C(=C(\\[O-])/C(F)(F)F)\\C(=O)C(F)(F)F.C(=C(\\[O-])/C(F)(F)F)\\C(=O)C(F)(F)F.[Cr+3]': <networkx.classes.graph.Graph at 0x7f36eb2df040>,
#  'C(=C(/[O-])\\C(F)(F)F)\\C(=O)C(F)(F)F.C(=C(/[O-])\\C(F)(F)F)\\C(=O)C(F)(F)F.C(=C(/[O-])\\C(F)(F)F)\\C(=O)C(F)(F)F.[Fe+3]': <networkx.classes.graph.Graph at 0x7f36eb2df0a0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[CH2].[CH]1C=CC=C1.[CH]1C=CC=C1.[Mn].[Mn]': <networkx.classes.graph.Graph at 0x7f36eb2df100>,
#  '[C+]=[Si-](CC)(CC)CC.[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Co].[Co].[Co]': <networkx.classes.graph.Graph at 0x7f36eb2df160>,
#  'CC1=NC([O])=CC=C1.CC1=NC([O])=CC=C1.CC1=NC([O])=CC=C1.CC1=NC([O])=CC=C1.[Cr].[Cr]': <networkx.classes.graph.Graph at 0x7f36eb2df1c0>,
#  'CC1=NC([O])=CC=C1.CC1=NC([O])=CC=C1.CC1=NC([O])=CC=C1.CC1=NC([O])=CC=C1.[Mo].[Mo]': <networkx.classes.graph.Graph at 0x7f36eb2df220>,
#  '[Ca]': <networkx.classes.graph.Graph at 0x7f36eb2df280>,
#  '[Cd]': <networkx.classes.graph.Graph at 0x7f36eb2df2e0>,
#  'CCCC.[Cd]': <networkx.classes.graph.Graph at 0x7f36eb2df340>,
#  'CCCCCC.[Cd]': <networkx.classes.graph.Graph at 0x7f36eb2df3a0>,
#  '[CH2][Si](C)(C)C.[CH2][Si](C)(C)C.[Cd]': <networkx.classes.graph.Graph at 0x7f36eb2df400>,
#  'C(Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb2df460>,
#  '[2H]C(=C(Cl)Cl)[2H]': <networkx.classes.graph.Graph at 0x7f36eb2df4c0>,
#  'FCl': <networkx.classes.graph.Graph at 0x7f36eb2df520>,
#  'FCl(F)F': <networkx.classes.graph.Graph at 0x7f36eb2df580>,
#  'ClCl': <networkx.classes.graph.Graph at 0x7f36eb2df5e0>,
#  'O=P(Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb2df640>,
#  'P(Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb2df6a0>,
#  'P(=S)(Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb2df700>,
#  'C[GeH](Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb2df760>,
#  'C[SiH](Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb2df7c0>,
#  'C[Si](Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb2df820>,
#  'C[GeH](C)Cl': <networkx.classes.graph.Graph at 0x7f36eb2df880>,
#  'C[SiH](C)Cl': <networkx.classes.graph.Graph at 0x7f36eb2df8e0>,
#  'C[Ge](C)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb2df940>,
#  'CCCCl': <networkx.classes.graph.Graph at 0x7f36eb2df9a0>,
#  'CC(C)Cl': <networkx.classes.graph.Graph at 0x7f36eb2dfa00>,
#  'CC(C)(C)Cl': <networkx.classes.graph.Graph at 0x7f36eb2dfa60>,
#  'C1=CC=NC=C1.ClI': <networkx.classes.graph.Graph at 0x7f36eb2dfac0>,
#  'Cl[Mo](N=O)(N=O)C1C=CC=C1': <networkx.classes.graph.Graph at 0x7f36eb2dfb20>,
#  'Cl[W](N=O)(N=O)C1C=CC=C1': <networkx.classes.graph.Graph at 0x7f36eb2dfb80>,
#  'P(Cl)(Cl)Cl.C(=O)=[Mo](=C=O)(=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb2dfbe0>,
#  'C1=CC=C(C=C1)Cl': <networkx.classes.graph.Graph at 0x7f36eb2dfc40>,
#  'Cl\\C=C\\Cl.C(=O)=[Fe](=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb2dfca0>,
#  'ClC(=C)Cl.C(=O)=[Fe](=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb2dfd00>,
#  'C1=CC(=CC=C1C=O)Cl': <networkx.classes.graph.Graph at 0x7f36eb2dfd60>,
#  'O=Cl(=O)(=O)F': <networkx.classes.graph.Graph at 0x7f36eb2dfdc0>,
#  'FS(F)(F)(F)(F)Cl': <networkx.classes.graph.Graph at 0x7f36eb2dfe20>,
#  'Cl[GeH3]': <networkx.classes.graph.Graph at 0x7f36eb2dfe80>,
#  'Cl': <networkx.classes.graph.Graph at 0x7f36eb2dfee0>,
#  '[SiH3]Cl': <networkx.classes.graph.Graph at 0x7f36eb2dff40>,
#  'ClI': <networkx.classes.graph.Graph at 0x7f36eb2dffa0>,
#  '[O-2].[O-2].[O-2].[Cl-].[Mn]': <networkx.classes.graph.Graph at 0x7f36eb054040>,
#  'N(=O)Cl': <networkx.classes.graph.Graph at 0x7f36eb0540a0>,
#  'O(OCl)Cl.[Cr]': <networkx.classes.graph.Graph at 0x7f36eb054100>,
#  'O=S(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb054160>,
#  'O=S(=O)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb0541c0>,
#  'S(SCl)Cl': <networkx.classes.graph.Graph at 0x7f36eb054220>,
#  '[O-2].[Cl-].[Cl-].[Cl-].[V]': <networkx.classes.graph.Graph at 0x7f36eb054280>,
#  'Cl[Ge](Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb0542e0>,
#  '[Si](Cl)(Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb054340>,
#  'Cl[Sn](Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb0543a0>,
#  'Cl[Ti](Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb054400>,
#  'Cl[V](Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb054460>,
#  'N1=P(N=P(N=P1(Cl)Cl)(Cl)Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb0544c0>,
#  'O([Si](Cl)(Cl)Cl)[Si](Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb054520>,
#  'N1=P(N=P(N=P(N=P1(Cl)Cl)(Cl)Cl)(Cl)Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb054580>,
#  'C/C(=C\\C(=O)C)/[O-].C/C(=C\\C(=O)C)/[O-].[Co+2]': <networkx.classes.graph.Graph at 0x7f36eb0545e0>,
#  'C(=O)=[Cr](=C=O)(=C=O)(=C=O)=C=O.P(F)(F)F.P(F)(F)F.P(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb054640>,
#  '[C-]#[O+].[C-]#[O+].[CH-]1C=CC=C1.[N-]=S.[Cr+6]': <networkx.classes.graph.Graph at 0x7f36eb0546a0>,
#  '[N-]=O.[N-]=O.[N-]=O.[N-]=O.[Cr+4]': <networkx.classes.graph.Graph at 0x7f36eb054700>,
#  '[Cs]': <networkx.classes.graph.Graph at 0x7f36eb054760>,
#  '[Br-].[Cs+]': <networkx.classes.graph.Graph at 0x7f36eb0547c0>,
#  '[Cl-].[Cs+]': <networkx.classes.graph.Graph at 0x7f36eb054820>,
#  '[F-].[Cs+]': <networkx.classes.graph.Graph at 0x7f36eb054880>,
#  '[I-].[Cs+]': <networkx.classes.graph.Graph at 0x7f36eb0548e0>,
#  '[N+](=O)([O-])[O-].[N+](=O)([O-])[O-].[Cu+2]': <networkx.classes.graph.Graph at 0x7f36eb054940>,
#  'CC(=O)/C=C(\\O[Al](O/C(=C\\C(=O)C)/C(F)(F)F)O/C(=C\\C(=O)C)/C(F)(F)F)/C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb0549a0>,
#  'FBr(F)F': <networkx.classes.graph.Graph at 0x7f36eb054a00>,
#  'C[GeH2]F': <networkx.classes.graph.Graph at 0x7f36eb054a60>,
#  'C[SiH2]F': <networkx.classes.graph.Graph at 0x7f36eb054ac0>,
#  'C[SiH](F)F': <networkx.classes.graph.Graph at 0x7f36eb054b20>,
#  'C[Ge](F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb054b80>,
#  'C[GeH](C)F': <networkx.classes.graph.Graph at 0x7f36eb054be0>,
#  'C(C(F)(F)F)O': <networkx.classes.graph.Graph at 0x7f36eb054c40>,
#  'C1C(N1)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb054ca0>,
#  'C(F)(F)(F)SC(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb054d00>,
#  'C#CC(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb054d60>,
#  'C=CC(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb054dc0>,
#  'C(=O)=[Mo](=C=O)=C=O.P(F)(F)F.P(F)(F)F.P(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb054e20>,
#  'FC(C(=O)O)(F)F.C[GeH2]C': <networkx.classes.graph.Graph at 0x7f36eb054e80>,
#  'C(=C(F)F)(C(F)(F)F)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb054ee0>,
#  'C(=O)=[Cr](=C=O)(=C=O)(=C=O)=C=O.P(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb054f40>,
#  'F[Si](F)(F)[Mn](=C=O)(=C=O)(=C=O)(=C=O)=C=O': <networkx.classes.graph.Graph at 0x7f36eb054fa0>,
#  'C(=O)=[Mo](=C=O)(=C=O)(=C=O)=C=O.P(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb055000>,
#  'C1=C(C=C(C(=C1F)F)F)F': <networkx.classes.graph.Graph at 0x7f36eb055060>,
#  'F': <networkx.classes.graph.Graph at 0x7f36eb0550c0>,
#  'FF': <networkx.classes.graph.Graph at 0x7f36eb055120>,
#  '[N-](F)F': <networkx.classes.graph.Graph at 0x7f36eb055180>,
#  'O(F)F': <networkx.classes.graph.Graph at 0x7f36eb0551e0>,
#  'O=S(=O)(F)F': <networkx.classes.graph.Graph at 0x7f36eb055240>,
#  'F[Xe]F': <networkx.classes.graph.Graph at 0x7f36eb0552a0>,
#  'N(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb055300>,
#  '[N+]([O-])(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb055360>,
#  'N#S(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb0553c0>,
#  'O=P(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb055420>,
#  'O(F)F.[V]': <networkx.classes.graph.Graph at 0x7f36eb055480>,
#  'FP(F)F': <networkx.classes.graph.Graph at 0x7f36eb0554e0>,
#  'FP(=S)(F)F': <networkx.classes.graph.Graph at 0x7f36eb055540>,
#  'F[Ge](F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb0555a0>,
#  'N(N(F)F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb055600>,
#  'F[Xe](F)(F)(F)=O': <networkx.classes.graph.Graph at 0x7f36eb055660>,
#  'FS(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb0556c0>,
#  'F[Si](F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb055720>,
#  'F[Ti](F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb055780>,
#  'F[Xe](F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb0557e0>,
#  'FI(F)(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb055840>,
#  'FP(F)(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb0558a0>,
#  'F[Sb](F)(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb055900>,
#  'F[V](F)(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb055960>,
#  'N1=P(N=P(N=P1(F)F)(F)F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb0559c0>,
#  'FS(F)(F)(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb055a20>,
#  'F[U](F)(F)(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb055a80>,
# ...
#  '[Mg]': <networkx.classes.graph.Graph at 0x7f36eb056560>,
#  'C1C=CC=[C-]1.C1C=CC=[C-]1.[Mg+2]': <networkx.classes.graph.Graph at 0x7f36eb0565c0>,
#  'C[Sn](C)C.[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Mn]': <networkx.classes.graph.Graph at 0x7f36eb056620>,
#  '[Mn]': <networkx.classes.graph.Graph at 0x7f36eb056680>,
#  'CC1=NC([O])=CC=C1.CC1=NC([O])=CC=C1.CC1=NC([O])=CC=C1.CC1=NC([O])=CC=C1.[Mn].[Mn]': <networkx.classes.graph.Graph at 0x7f36eb0566e0>,
#  '[BH3-][N+](C)(C)C': <networkx.classes.graph.Graph at 0x7f36eb056740>,
#  'B(CC)(CC)N': <networkx.classes.graph.Graph at 0x7f36eb0567a0>,
#  'C1=CN=CC=C1Br': <networkx.classes.graph.Graph at 0x7f36eb056800>,
#  'C(#N)Cl': <networkx.classes.graph.Graph at 0x7f36eb056860>,
#  'C(C#N)Cl': <networkx.classes.graph.Graph at 0x7f36eb0568c0>,
#  'C(#N)C(Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eb056920>,
#  'CC(=O)N': <networkx.classes.graph.Graph at 0x7f36eb056980>,
#  'CNC': <networkx.classes.graph.Graph at 0x7f36eb0569e0>,
#  'CCN': <networkx.classes.graph.Graph at 0x7f36eb056a40>,
#  'C(CO)N': <networkx.classes.graph.Graph at 0x7f36eb056aa0>,
#  'C(CN)N': <networkx.classes.graph.Graph at 0x7f36eb056b00>,
#  'C(CCl)C#N': <networkx.classes.graph.Graph at 0x7f36eb056b60>,
#  'C=CCN.Cl': <networkx.classes.graph.Graph at 0x7f36eb056bc0>,
#  'C(C#N)C#N': <networkx.classes.graph.Graph at 0x7f36eb056c20>,
#  'CCC#N': <networkx.classes.graph.Graph at 0x7f36eb056c80>,
#  'CN(C)C#N': <networkx.classes.graph.Graph at 0x7f36eb056ce0>,
#  'CCCN': <networkx.classes.graph.Graph at 0x7f36eb056d40>,
#  'C(CN)CO': <networkx.classes.graph.Graph at 0x7f36eb056da0>,
#  'COCCN': <networkx.classes.graph.Graph at 0x7f36eb056e00>,
#  'CP(=N)(C)C': <networkx.classes.graph.Graph at 0x7f36eb056e60>,
#  'C(CN)CN': <networkx.classes.graph.Graph at 0x7f36eb056ec0>,
#  'C(=C/C#N)\\C#N': <networkx.classes.graph.Graph at 0x7f36eb056f20>,
#  'C#CCC#[NH+]': <networkx.classes.graph.Graph at 0x7f36eb056f80>,
#  'C=CCC#N': <networkx.classes.graph.Graph at 0x7f36eb056fe0>,
#  'COC(=O)CC#N': <networkx.classes.graph.Graph at 0x7f36eb057040>,
#  'CCCC#N': <networkx.classes.graph.Graph at 0x7f36eb0570a0>,
#  'CC(C)[N+]#[C-]': <networkx.classes.graph.Graph at 0x7f36eb057100>,
#  'C1CCNC1': <networkx.classes.graph.Graph at 0x7f36eb057160>,
#  'CC(=O)N(C)C': <networkx.classes.graph.Graph at 0x7f36eb0571c0>,
#  'CC(=O)NN(C)C': <networkx.classes.graph.Graph at 0x7f36eb057220>,
#  'CCNCC': <networkx.classes.graph.Graph at 0x7f36eb057280>,
#  'CCCCN': <networkx.classes.graph.Graph at 0x7f36eb0572e0>,
#  'CCC(C)N': <networkx.classes.graph.Graph at 0x7f36eb057340>,
#  'CC(C)(C)N': <networkx.classes.graph.Graph at 0x7f36eb0573a0>,
#  'C1=CN=CC=C1Cl': <networkx.classes.graph.Graph at 0x7f36eb057400>,
#  'C1=CC(=CN=C1)Cl': <networkx.classes.graph.Graph at 0x7f36eb057460>,
#  'C1=CC=NC(=C1)Cl': <networkx.classes.graph.Graph at 0x7f36eb0574c0>,
#  'C1=CN=CC=C1F': <networkx.classes.graph.Graph at 0x7f36eb057520>,
#  'C1=CC(=CN=C1)F': <networkx.classes.graph.Graph at 0x7f36eb057580>,
#  'C1=CC=NC(=C1)F': <networkx.classes.graph.Graph at 0x7f36eb0575e0>,
#  'C1=CN=CC=C1[N+](=O)[O-]': <networkx.classes.graph.Graph at 0x7f36eb057640>,
#  'C1=CC(=CN=C1)[N+](=O)[O-]': <networkx.classes.graph.Graph at 0x7f36eb0576a0>,
#  'C1=CC=NC(=C1)[N+](=O)[O-]': <networkx.classes.graph.Graph at 0x7f36eb057700>,
#  'C1=CC=NC=C1': <networkx.classes.graph.Graph at 0x7f36eb057760>,
#  'C1=CNC=CC1=O': <networkx.classes.graph.Graph at 0x7f36eb0577c0>,
#  'C1=CC(=O)NC=C1': <networkx.classes.graph.Graph at 0x7f36eb057820>,
#  'C1=CC=[N+](C=C1)[O-]': <networkx.classes.graph.Graph at 0x7f36eb057880>,
#  'C1=CNC(=O)C(=C1)O': <networkx.classes.graph.Graph at 0x7f36eb0578e0>,
#  'C1=CC=NC(=C1)N': <networkx.classes.graph.Graph at 0x7f36eb057940>,
#  'CC1=CC(=CN=C1)N': <networkx.classes.graph.Graph at 0x7f36eb0579a0>,
#  'C1=CN=CC=C1N': <networkx.classes.graph.Graph at 0x7f36eb057a00>,
#  'CCCCC#N': <networkx.classes.graph.Graph at 0x7f36eb057a60>,
#  'CCCCN=C=O': <networkx.classes.graph.Graph at 0x7f36eb057ac0>,
#  'C1CCNCC1': <networkx.classes.graph.Graph at 0x7f36eb057b20>,
#  'C(CCN)CCN': <networkx.classes.graph.Graph at 0x7f36eb057b80>,
#  'C1=CC(=CC=C1N)Cl': <networkx.classes.graph.Graph at 0x7f36eb057be0>,
#  'C1=CC(=CC(=C1)Cl)N': <networkx.classes.graph.Graph at 0x7f36eb057c40>,
#  'C1=CC(=CN=C1)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb057ca0>,
#  'C1=CN=CC=C1C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb057d00>,
#  'C1=CC=NC(=C1)C(F)(F)F': <networkx.classes.graph.Graph at 0x7f36eb057d60>,
#  'C1=CC=NC(=C1)C#N': <networkx.classes.graph.Graph at 0x7f36eb057dc0>,
#  'C1=CC(=CN=C1)C#N': <networkx.classes.graph.Graph at 0x7f36eb057e20>,
#  'C1=CN=CC=C1C#N': <networkx.classes.graph.Graph at 0x7f36eb057e80>,
#  'C1=CN=CC=C1C=O': <networkx.classes.graph.Graph at 0x7f36eb057ee0>,
#  'C1=CC=C(C=C1)[N+](=O)[O-]': <networkx.classes.graph.Graph at 0x7f36eb057f40>,
#  'C1=CC(=CC(=C1)[N+](=O)[O-])N': <networkx.classes.graph.Graph at 0x7f36eb057fa0>,
#  'CC1=CC=CC=N1': <networkx.classes.graph.Graph at 0x7f36eaf30040>,
#  'CC1=CC=NC=C1': <networkx.classes.graph.Graph at 0x7f36eaf300a0>,
#  'CC1=CN=CC=C1': <networkx.classes.graph.Graph at 0x7f36eaf30100>,
#  'C1=CC(=CC=C1N)O': <networkx.classes.graph.Graph at 0x7f36eaf30160>,
#  'C1=CC(=CC(=C1)O)N': <networkx.classes.graph.Graph at 0x7f36eaf301c0>,
#  'COC1=CC=NC=C1': <networkx.classes.graph.Graph at 0x7f36eaf30220>,
#  'COC1=CN=CC=C1': <networkx.classes.graph.Graph at 0x7f36eaf30280>,
#  'CCN1C=CC=C1C=O': <networkx.classes.graph.Graph at 0x7f36eaf302e0>,
#  'CC(=O)C1=CC=CN1': <networkx.classes.graph.Graph at 0x7f36eaf30340>,
#  'COC1=CC=CC=N1': <networkx.classes.graph.Graph at 0x7f36eaf303a0>,
#  'CCN1CCCC1=O': <networkx.classes.graph.Graph at 0x7f36eaf30400>,
#  'C1CN2CCN1CC2': <networkx.classes.graph.Graph at 0x7f36eaf30460>,
#  'C1CCC(CC1)N': <networkx.classes.graph.Graph at 0x7f36eaf304c0>,
#  'CCN(CC)C(=O)C': <networkx.classes.graph.Graph at 0x7f36eaf30520>,
#  'CCN(CC)CC': <networkx.classes.graph.Graph at 0x7f36eaf30580>,
#  'CCCCNCC': <networkx.classes.graph.Graph at 0x7f36eaf305e0>,
#  'CC(C)NC(C)C': <networkx.classes.graph.Graph at 0x7f36eaf30640>,
#  'C(CCCN)CCN': <networkx.classes.graph.Graph at 0x7f36eaf306a0>,
#  'CN1N2N(P3N(N1P(P(N2C)P3C)C)C)C': <networkx.classes.graph.Graph at 0x7f36eaf30700>,
#  'C1=CC(=CC=C1C#N)N': <networkx.classes.graph.Graph at 0x7f36eaf30760>,
#  'CC(=O)C1=CC=NC=C1': <networkx.classes.graph.Graph at 0x7f36eaf307c0>,
#  'CC(=O)C1=CN=CC=C1': <networkx.classes.graph.Graph at 0x7f36eaf30820>,
#  'CC(=O)C1=CC=CC=N1': <networkx.classes.graph.Graph at 0x7f36eaf30880>,
#  'CC1=CC=C(C=C1)N': <networkx.classes.graph.Graph at 0x7f36eaf308e0>,
#  'CC1=CC(=CC=C1)N': <networkx.classes.graph.Graph at 0x7f36eaf30940>,
#  'CCN1C=CC=C(C1=O)O': <networkx.classes.graph.Graph at 0x7f36eaf309a0>,
#  'CC1=C(C=CC=C1N)N': <networkx.classes.graph.Graph at 0x7f36eaf30a00>,
#  'CC1=CC(=C(C=C1)N)N': <networkx.classes.graph.Graph at 0x7f36eaf30a60>,
#  'C1CN2CCC1CC2': <networkx.classes.graph.Graph at 0x7f36eaf30ac0>,
#  'CN(C)CCCN(C)C': <networkx.classes.graph.Graph at 0x7f36eaf30b20>,
#  'CCNC1=CC=CC=C1': <networkx.classes.graph.Graph at 0x7f36eaf30b80>,
#  'CN(C)C1=CC=CC=C1': <networkx.classes.graph.Graph at 0x7f36eaf30be0>,
#  'CCCCNCCCC': <networkx.classes.graph.Graph at 0x7f36eaf30c40>,
#  'CN(C)CCCCN(C)C': <networkx.classes.graph.Graph at 0x7f36eaf30ca0>,
#  'CCC1=CC=CC(=C1N)C': <networkx.classes.graph.Graph at 0x7f36eaf30d00>,
#  'CCCN(CCC)CCC': <networkx.classes.graph.Graph at 0x7f36eaf30d60>,
#  'C1=CC=C2C(=C1)C=CC=C2N': <networkx.classes.graph.Graph at 0x7f36eaf30dc0>,
#  'C1CN1CCC2=CC=CC=C2': <networkx.classes.graph.Graph at 0x7f36eaf30e20>,
#  'CCN(CC)C1=CC=CC=C1': <networkx.classes.graph.Graph at 0x7f36eaf30e80>,
#  'CN(C)C1=CC=C(C=C1)N(C)C': <networkx.classes.graph.Graph at 0x7f36eaf30ee0>,
#  'CN(C)CCCCCCN(C)C': <networkx.classes.graph.Graph at 0x7f36eaf30f40>,
#  'C1=CC=C2C(=C1)C=CC=C2C[N-]N': <networkx.classes.graph.Graph at 0x7f36eaf30fa0>,
#  'C1C2CC3CC1CC(C2)(C3)C#N': <networkx.classes.graph.Graph at 0x7f36eaf31000>,
#  'C1CCC(CC1)N=CC2=CC=CC=C2': <networkx.classes.graph.Graph at 0x7f36eaf31060>,
#  'CN(C)C1=CC=CC2=C1C(=CC=C2)N(C)C': <networkx.classes.graph.Graph at 0x7f36eaf310c0>,
#  'N': <networkx.classes.graph.Graph at 0x7f36eaf31120>,
#  'NN': <networkx.classes.graph.Graph at 0x7f36eaf31180>,
#  '[N]=O': <networkx.classes.graph.Graph at 0x7f36eaf311e0>,
#  'N(=O)[O]': <networkx.classes.graph.Graph at 0x7f36eaf31240>,
#  'N#N': <networkx.classes.graph.Graph at 0x7f36eaf312a0>,
#  '[N-]=[N+]=O': <networkx.classes.graph.Graph at 0x7f36eaf31300>,
#  'N1=S=NS1': <networkx.classes.graph.Graph at 0x7f36eaf31360>,
#  '[N+](=O)([O-])[O-].[N+](=O)([O-])[O-].[N+](=O)([O-])[O-].[N+](=O)([O-])[O-].[Ti+4]': <networkx.classes.graph.Graph at 0x7f36eaf313c0>,
#  'N1=S=NSN=S=NS1': <networkx.classes.graph.Graph at 0x7f36eaf31420>,
#  '[Na]': <networkx.classes.graph.Graph at 0x7f36eaf31480>,
#  '[Ne]': <networkx.classes.graph.Graph at 0x7f36eaf314e0>,
#  'C1C=CC=[C-]1.C1C=CC=[C-]1.[Ni+2]': <networkx.classes.graph.Graph at 0x7f36eaf31540>,
#  'C(C(F)(F)F)[O-]': <networkx.classes.graph.Graph at 0x7f36eaf315a0>,
#  'C1CO1': <networkx.classes.graph.Graph at 0x7f36eaf31600>,
#  'CC(=O)O': <networkx.classes.graph.Graph at 0x7f36eaf31660>,
#  'C(=C/O)\\C=O': <networkx.classes.graph.Graph at 0x7f36eaf316c0>,
#  'CCCO': <networkx.classes.graph.Graph at 0x7f36eaf31720>,
#  'CC(C)O': <networkx.classes.graph.Graph at 0x7f36eaf31780>,
#  'CP(C)CO': <networkx.classes.graph.Graph at 0x7f36eaf317e0>,
#  'CC(=O)OCC#N': <networkx.classes.graph.Graph at 0x7f36eaf31840>,
#  'CC(C=O)C=O': <networkx.classes.graph.Graph at 0x7f36eaf318a0>,
#  'CC(C)C(=O)O': <networkx.classes.graph.Graph at 0x7f36eaf31900>,
#  'CCOCC': <networkx.classes.graph.Graph at 0x7f36eaf31960>,
#  'CC(C)(C)O': <networkx.classes.graph.Graph at 0x7f36eaf319c0>,
#  '[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[C-]#[O+].[Mn].[Br-]': <networkx.classes.graph.Graph at 0x7f36eaf31a20>,
#  'CCC(=O)C(=O)C': <networkx.classes.graph.Graph at 0x7f36eaf31a80>,
#  'CC(=O)CC(=S)C': <networkx.classes.graph.Graph at 0x7f36eaf31ae0>,
#  'CN1C=CC=CC1=O': <networkx.classes.graph.Graph at 0x7f36eaf31b40>,
#  'CN1C=CC=C1C=O': <networkx.classes.graph.Graph at 0x7f36eaf31ba0>,
#  'C/C(=C\\C(=O)C)/SC': <networkx.classes.graph.Graph at 0x7f36eaf31c00>,
#  'C1=CC=C(C(=C1)C=O)O': <networkx.classes.graph.Graph at 0x7f36eaf31c60>,
#  'C1=CC=C(C=C1)C(=O)O': <networkx.classes.graph.Graph at 0x7f36eaf31cc0>,
#  'OC=C1C=CC=C1C=O': <networkx.classes.graph.Graph at 0x7f36eaf31d20>,
#  'C1=CC(=O)N(C=C1)CCO': <networkx.classes.graph.Graph at 0x7f36eaf31d80>,
#  'CC(C)CC(=O)C(=O)C': <networkx.classes.graph.Graph at 0x7f36eaf31de0>,
#  'C(CC)OC(\\C=C(\\C)/S)=O': <networkx.classes.graph.Graph at 0x7f36eaf31e40>,
#  'CC(=O)C1=CC=CC=C1O': <networkx.classes.graph.Graph at 0x7f36eaf31ea0>,
#  'COC(=O)C1=CC=CC=C1': <networkx.classes.graph.Graph at 0x7f36eaf31f00>,
#  'C(C)(=O)C1C(CCCC1)=S': <networkx.classes.graph.Graph at 0x7f36eaf31f60>,
#  'C(C)(=S)C1C(CCCC1)=O': <networkx.classes.graph.Graph at 0x7f36eaf31fc0>,
#  'OC1=CC=C2C=CC=C3C=CC(C1=C32)=O': <networkx.classes.graph.Graph at 0x7f36eaf32020>,
#  'CC1=CC(=CC(=C1C(=O)C)C)C(C)(C)C': <networkx.classes.graph.Graph at 0x7f36eaf32080>,
#  'O=S(F)F': <networkx.classes.graph.Graph at 0x7f36eaf320e0>,
#  'O': <networkx.classes.graph.Graph at 0x7f36eaf32140>,
#  'OO': <networkx.classes.graph.Graph at 0x7f36eaf321a0>,
#  'O([SiH3])[SiH3]': <networkx.classes.graph.Graph at 0x7f36eaf32200>,
#  'N(=O)[O-].[O-2].[Ti+3]': <networkx.classes.graph.Graph at 0x7f36eaf32260>,
#  'O=O': <networkx.classes.graph.Graph at 0x7f36eaf322c0>,
#  'O=S=O': <networkx.classes.graph.Graph at 0x7f36eaf32320>,
#  '[O-][O+]=O': <networkx.classes.graph.Graph at 0x7f36eaf32380>,
#  'O=S(=O)=O': <networkx.classes.graph.Graph at 0x7f36eaf323e0>,
#  'O1P2OP3OP1OP(O2)O3': <networkx.classes.graph.Graph at 0x7f36eaf32440>,
#  'CP(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eaf324a0>,
#  'CP(=S)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eaf32500>,
#  'C(P(=O)(Cl)Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eaf32560>,
#  'COP(=S)(OC)Cl': <networkx.classes.graph.Graph at 0x7f36eaf325c0>,
#  'COP(=O)(C)OC': <networkx.classes.graph.Graph at 0x7f36eaf32620>,
#  'COP(=O)(OC)SC': <networkx.classes.graph.Graph at 0x7f36eaf32680>,
#  'CCP(CC)CC': <networkx.classes.graph.Graph at 0x7f36eaf326e0>,
#  'P': <networkx.classes.graph.Graph at 0x7f36eaf32740>,
#  'P12P3P1P23': <networkx.classes.graph.Graph at 0x7f36eaf327a0>,
#  'P12P3P1SP(S2)S3': <networkx.classes.graph.Graph at 0x7f36eaf32800>,
#  'CP': <networkx.classes.graph.Graph at 0x7f36eaf32860>,
#  'CPC': <networkx.classes.graph.Graph at 0x7f36eaf328c0>,
#  'COP(=S)(OC)OC': <networkx.classes.graph.Graph at 0x7f36eaf32920>,
#  'CP(=S)(C)C': <networkx.classes.graph.Graph at 0x7f36eaf32980>,
#  'C1=CC=PC=C1': <networkx.classes.graph.Graph at 0x7f36eaf329e0>,
#  '[Pb]': <networkx.classes.graph.Graph at 0x7f36eaf32a40>,
#  'C[Pb](C)(C)C': <networkx.classes.graph.Graph at 0x7f36eaf32aa0>,
#  '[Rb]': <networkx.classes.graph.Graph at 0x7f36eaf32b00>,
#  'C1C/C(=C\\C(=O)O)/C=C1C2=CC=CC=C2.[Rh]': <networkx.classes.graph.Graph at 0x7f36eaf32b60>,
#  'S': <networkx.classes.graph.Graph at 0x7f36eaf32bc0>,
#  'S1SSSSSSS1': <networkx.classes.graph.Graph at 0x7f36eaf32c20>,
#  'C1=CSS2=C1C=CS2': <networkx.classes.graph.Graph at 0x7f36eaf32c80>,
#  'C(C)(=S)CC(C)=O': <networkx.classes.graph.Graph at 0x7f36eaf32ce0>,
#  'CSC(=CC(C)=O)C': <networkx.classes.graph.Graph at 0x7f36eaf32d40>,
#  'CC1SS2SC(=CC2=C1)C': <networkx.classes.graph.Graph at 0x7f36eaf32da0>,
#  'S\\C(=C/C(=O)OCCC)\\C': <networkx.classes.graph.Graph at 0x7f36eaf32e00>,
#  '[SiH3]S[SiH3]': <networkx.classes.graph.Graph at 0x7f36eaf32e60>,
#  '[Sb].[Sb].[Sb].[Sb]': <networkx.classes.graph.Graph at 0x7f36eaf32ec0>,
#  '[Se].[Se].[Se].[Se]': <networkx.classes.graph.Graph at 0x7f36eaf32f20>,
#  '[GeH3][Se][GeH3]': <networkx.classes.graph.Graph at 0x7f36eaf32f80>,
#  '[SeH2]': <networkx.classes.graph.Graph at 0x7f36eaf32fe0>,
#  '[SiH3][Se][SiH3]': <networkx.classes.graph.Graph at 0x7f36eaf33040>,
#  'C=C[Si](Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eaf330a0>,
#  'CC[Si](Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eaf33100>,
#  'C[Si](C=C)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eaf33160>,
#  'C=CC[Si](Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eaf331c0>,
#  'CC[Si](CC)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eaf33220>,
#  'CO[Si](OC)(OC)OC': <networkx.classes.graph.Graph at 0x7f36eaf33280>,
#  'C[Si](C)(C)C.O': <networkx.classes.graph.Graph at 0x7f36eaf332e0>,
#  'C[Si](C)(CC=C)Cl': <networkx.classes.graph.Graph at 0x7f36eaf33340>,
#  'C[Si](C)(C)CCO': <networkx.classes.graph.Graph at 0x7f36eaf333a0>,
#  'CC[Si](CC)(CC)Cl': <networkx.classes.graph.Graph at 0x7f36eaf33400>,
#  'C1=CC=C(C=C1)[Si](Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eaf33460>,
#  'CCO[Si](C)(C)OCC': <networkx.classes.graph.Graph at 0x7f36eaf334c0>,
#  'CCO[Si](C)(OCC)OCC': <networkx.classes.graph.Graph at 0x7f36eaf33520>,
#  'C=C[Si](C=C)(C=C)C=C': <networkx.classes.graph.Graph at 0x7f36eaf33580>,
#  'CCO[Si](OCC)(OCC)OCC': <networkx.classes.graph.Graph at 0x7f36eaf335e0>,
#  '[SiH](Cl)(Cl)Cl': <networkx.classes.graph.Graph at 0x7f36eaf33640>,
#  '[SiH4]': <networkx.classes.graph.Graph at 0x7f36eaf336a0>,
#  '[SiH3][SiH3]': <networkx.classes.graph.Graph at 0x7f36eaf33700>,
#  '[SiH3][Te][SiH3]': <networkx.classes.graph.Graph at 0x7f36eaf33760>,
#  '[SnH4]': <networkx.classes.graph.Graph at 0x7f36eaf337c0>,
#  'Br[Sn]Br': <networkx.classes.graph.Graph at 0x7f36eaf33820>,
#  'Cl[Sn]Cl': <networkx.classes.graph.Graph at 0x7f36eaf33880>,
#  '[Sr]': <networkx.classes.graph.Graph at 0x7f36eaf338e0>,
#  'O1NC=C2C=NO[TeH]12': <networkx.classes.graph.Graph at 0x7f36eaf33940>,
#  '[Te][Te]': <networkx.classes.graph.Graph at 0x7f36eaf339a0>,
#  '[Ti]': <networkx.classes.graph.Graph at 0x7f36eaf33a00>,
#  '[O-2].[F-].[F-].[F-].[V]': <networkx.classes.graph.Graph at 0x7f36eaf33a60>,
#  '[Xe]': <networkx.classes.graph.Graph at 0x7f36eaf33ac0>,
#  'O(OOOF)F.[Xe]': <networkx.classes.graph.Graph at 0x7f36eaf33b20>,
#  '[Zn]': <networkx.classes.graph.Graph at 0x7f36eaf33b80>,
#  'C[CH2-].C[CH2-].[Zn+2]': <networkx.classes.graph.Graph at 0x7f36eaf33be0>}

# %%
print(" ")
print(f"We have {len(train_data.keys())} molecular graphs to train with.")
print("Please adhere to best practices during training.\n")

print("The networkx graphs in the graph_data.json file are lablled by SMILES strings")
print("For more details on SMILES, visit: https://en.wikipedia.org/wiki/Simplified_molecular-input_line-entry_system\n")
print("Below is an example of the graph nodes called by the SMILE string C[CH2-].C[CH2-].[Zn+2].\n")

print("Graph Nodes:")
for node, data in graph.nodes(data=True):
     print(f"Node {node}: {data}")

print("\nGraph Edges:")
for u, v, data in graph.edges(data=True):  
     print(f"Edge ({u}, {v}): {data}")
print(" ")

print("Let's examine the organization of the nodes by printing node 0:")
print("Remember, the index has no inherent meaning;")
print("your results should be consistent even if these indices are permuted.")
print("Permutation Invariance!\n")

print("'atom_type', 'formal_charge' and 'orbitals' are the attributes available for node featurization, 'binding_energies' are the node labels to predict:\n")
print("\t'atom_type' represents the atomic number, or the number of protons in an atom's nucleus.")
print("\t\tThis number differentiates elements, e.g., 6 for carbon and 1 for hydrogen.")
print("\t\tThis dataset contains 55 different atom types, use a one-hot encoding vector of length 55,")
print("\t\t... or try different atom representations available in the literature (SkipAtom, Mat2Vec ...)\n")

print("\t'formal_charge' is the integer charge of the atom in the molecule.\n")

print("\t'orbitals' is a vector of the orbitals types with binding energy values.")
print("\t\tThe length of this vector is same length as the binding energies vector.\n")

print("\t'binding_energies' is a vector of the output node labels to predict.\n")

print("The binding energy data is sparse, many of the orbitals and binding energies above are assigned -1 dummy values.\n")

print("Furthermore, some graph nodes will have many binding energy values.")
print("There are even some single atom graphs in the data.")
print("For example the Xe atom (SMILE string [Xe]) has many binding energies:\n")

atom_graph = train_data["[Xe]"]
print("Graph for [Xe]:")
print(atom_graph.nodes(data=True))
print(" ")

print("We suggest two ideas for handling the multidimensional nature of the outputs in the project presentation slides.\n") 

print("For the edges, the 'bond_type' feature is categorical and given as a string.\n") 
print("\tPossible types are SINGLE, DOUBLE, TRIPLE. use a one-hot encoding for the bond-types.")
print("\tIn the example above, Node 4 is not bonded to any other atoms.") 
print("\tTherefore you should turn this data into fully connected graphs and create another 'bond_type' catergory called NONE.\n")

print("One possible way to improve the predictions is to include more features to the graphs")
print("This can be done through modifying database_2_graph.py, see the comment in line 323 of this code")
print("This would will reduce the size of the traning data as the modification will induce rdkit errors,")
print("for some molecules.\n")

print("The following google colab tutorial is good starting point for molecular graph neural networks in PyTorch:\n")

print("https://colab.research.google.com/github/chaitjo/geometric-gnn-dojo/blob/main/geometric_gnn_101.ipynb")

print("\nThe conda envrionment for this project will enable you to run the code from this tutorial on the gpu's provided\n")

print("Only the intro and Part 0 of the tutorial is appliciable for this project, as the present data does not contain") 
print("molecular geometry information.\n")
# Out:
#
# We have 861 molecular graphs to train with.
# Please adhere to best practices during training.
#
# The networkx graphs in the graph_data.json file are lablled by SMILES strings
# For more details on SMILES, visit: https://en.wikipedia.org/wiki/Simplified_molecular-input_line-entry_system
#
# Below is an example of the graph nodes called by the SMILE string C[CH2-].C[CH2-].[Zn+2].
#
# Graph Nodes:
# Node 0: {'atom_type': 'C', 'formal_charge': 0, 'orbitals': [-1], 'binding_energies': [-1]}
# Node 1: {'atom_type': 'C', 'formal_charge': -1, 'orbitals': [-1], 'binding_energies': [-1]}
# Node 2: {'atom_type': 'C', 'formal_charge': 0, 'orbitals': [-1], 'binding_energies': [-1]}
# Node 3: {'atom_type': 'C', 'formal_charge': -1, 'orbitals': [-1], 'binding_energies': [-1]}
# Node 4: {'atom_type': 'Zn', 'formal_charge': 2, 'orbitals': ['3d5/2'], 'binding_energies': [16.709]}
#
# Graph Edges:
# Edge (0, 1): {'bond_type': 'SINGLE'}
# Edge (2, 3): {'bond_type': 'SINGLE'}
#
# Let's examine the organization of the nodes by printing node 0:
# Remember, the index has no inherent meaning;
# your results should be consistent even if these indices are permuted.
# Permutation Invariance!
#
# 'atom_type', 'formal_charge' and 'orbitals' are the attributes available for node featurization, 'binding_energies' are the node labels to predict:
#
# 	'atom_type' represents the atomic number, or the number of protons in an atom's nucleus.
# 		This number differentiates elements, e.g., 6 for carbon and 1 for hydrogen.
# 		This dataset contains 55 different atom types, use a one-hot encoding vector of length 55,
# 		... or try different atom representations available in the literature (SkipAtom, Mat2Vec ...)
#
# 	'formal_charge' is the integer charge of the atom in the molecule.
#
# 	'orbitals' is a vector of the orbitals types with binding energy values.
# 		The length of this vector is same length as the binding energies vector.
#
# 	'binding_energies' is a vector of the output node labels to predict.
#
# The binding energy data is sparse, many of the orbitals and binding energies above are assigned -1 dummy values.
#
# Furthermore, some graph nodes will have many binding energy values.
# There are even some single atom graphs in the data.
# For example the Xe atom (SMILE string [Xe]) has many binding energies:
#
# Graph for [Xe]:
# [(0, {'atom_type': 'Xe', 'formal_charge': 0, 'orbitals': ['3s', '3d5/2', '3p3/2', '4s', '4p3/2', '4d5/2'], 'binding_energies': [1148.7, 676.5133333333334, 940.6, 213.26, 145.505, 67.5]})]
#
# We suggest two ideas for handling the multidimensional nature of the outputs in the project presentation slides.
#
# For the edges, the 'bond_type' feature is categorical and given as a string.
#
# 	Possible types are SINGLE, DOUBLE, TRIPLE. use a one-hot encoding for the bond-types.
# 	In the example above, Node 4 is not bonded to any other atoms.
# 	Therefore you should turn this data into fully connected graphs and create another 'bond_type' catergory called NONE.
#
# One possible way to improve the predictions is to include more features to the graphs
# This can be done through modifying database_2_graph.py, see the comment in line 323 of this code
# This would will reduce the size of the traning data as the modification will induce rdkit errors,
# for some molecules.
#
# The following google colab tutorial is good starting point for molecular graph neural networks in PyTorch:
#
# https://colab.research.google.com/github/chaitjo/geometric-gnn-dojo/blob/main/geometric_gnn_101.ipynb
#
# The conda envrionment for this project will enable you to run the code from this tutorial on the gpu's provided
#
# Only the intro and Part 0 of the tutorial is appliciable for this project, as the present data does not contain
# molecular geometry information.
